# %%
import os
import pathlib
from PIL import Image
path="..\\dataset"
path=pathlib.Path(path)

# %%
import shutil
for i in path.glob("*"):
    folder=str(i).split("\\")[-1]
    if(True):
        for j in i.glob("*"):
            print(j)
            fruit_veggie=str(j).split("\\")[-1]
            # print(fruit_veggie)
            for k in os.listdir(j):
                new_path="..\\newdataset_combine\\train\\"+fruit_veggie
                if not os.path.isdir(new_path):
                    os.makedirs(new_path)
                old_path=str(j)+"\\"+k
                # print(old_path)
                # print("Moving From ",old_path," to ",new_path)
                im1=Image.open(old_path).convert("RGB")
                # print(k)
                name=k.split(".")[0]
                # print(name)
                im1.save(new_path+"\\"+name+".jpeg")
                # exit(0)
                # print(new_path)
            # print(j)
    # else:
    #     new_path="..\\newdataset\\train"
    #     old_path="..\\dataset\\train"
    #     os.makedirs(new_path)
    #     shutil.move(old_path,new_path)
# Out:
# ..\dataset\test\Apple
# ..\dataset\test\banana
# ..\dataset\test\Bean
# ..\dataset\test\Beetroot
# ..\dataset\test\Bitter_Gourd
# ..\dataset\test\Bottle_Gourd
# ..\dataset\test\Brinjal
# ..\dataset\test\Broccoli
# ..\dataset\test\Cabbage
# ..\dataset\test\Capsicum
# ..\dataset\test\Carrot
# ..\dataset\test\Cauliflower
# ..\dataset\test\Cucumber
# ..\dataset\test\custard_apple
# ..\dataset\test\DragonFruit
# ..\dataset\test\fig
# ..\dataset\test\Garlic
# ..\dataset\test\Ginger
# c:\Users\santo\AppData\Local\Programs\Python\Python38\lib\site-packages\PIL\Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# ..\dataset\test\grape
# ..\dataset\test\Guava
# ..\dataset\test\jackfruit
# ..\dataset\test\Kiwi
# ..\dataset\test\lemon
# ..\dataset\test\mango
# ..\dataset\test\Mosambi
# ..\dataset\test\Muskmelon
# ..\dataset\test\Okra
# ..\dataset\test\onion
# ..\dataset\test\orange
# ..\dataset\test\Papaya
# ...
