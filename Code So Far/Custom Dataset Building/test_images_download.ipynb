# %%
import bs4
import requests
from selenium import webdriver
import os
import time
from selenium.webdriver.common.keys import Keys
import pathlib
from PIL import Image

# %%
key_word_path="..\\..\\final_dataset\\train"
key_word_path=pathlib.Path(key_word_path)
key_words=[]
for i in key_word_path.glob("*"):
    temp=str(i).split("\\")[-1]
    key_words.append(temp)
print(key_words)
# Out:
# ['Apple', 'Banana', 'Bean', 'Beetroot', 'Bitter gourd', 'Bottle gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Custard apple', 'Dragonfruit', 'Fig', 'Garlic', 'Ginger', 'Grape', 'Guava', 'Jackfruit', 'Kiwi', 'Lemon', 'Mango', 'Mosambi', 'Muskmelon', 'Okra', 'Onion', 'Orange', 'Papaya', 'Pear', 'Peas', 'Pineapple', 'Pomegranate', 'Potato', 'Pumpkin', 'Radish', 'Sapodilla', 'Strawberry', 'Sweet potato', 'Tomato', 'Watermelon']

# %%
colours_dict={}
for i in key_words:
    colours_dict[i]=''
colours_dict
# Out:
# {'Apple': '',
#  'Banana': '',
#  'Bean': '',
#  'Beetroot': '',
#  'Bitter gourd': '',
#  'Bottle gourd': '',
#  'Brinjal': '',
#  'Broccoli': '',
#  'Cabbage': '',
#  'Capsicum': '',
#  'Carrot': '',
#  'Cauliflower': '',
#  'Cucumber': '',
#  'Custard apple': '',
#  'Dragonfruit': '',
#  'Fig': '',
#  'Garlic': '',
#  'Ginger': '',
#  'Grape': '',
#  'Guava': '',
#  'Jackfruit': '',
#  'Kiwi': '',
#  'Lemon': '',
#  'Mango': '',
#  'Mosambi': '',
#  'Muskmelon': '',
#  'Okra': '',
#  'Onion': '',
#  'Orange': '',
#  'Papaya': '',
#  'Pear': '',
#  'Peas': '',
#  'Pineapple': '',
#  'Pomegranate': '',
#  'Potato': '',
#  'Pumpkin': '',
#  'Radish': '',
#  'Sapodilla': '',
#  'Strawberry': '',
#  'Sweet potato': '',
#  'Tomato': '',
#  'Watermelon': ''}

# %%
for i in colours_dict:
    color=input("Enter the Colour of the Fruit or Vegetable to be stored "+i+" :")
    colours_dict[i]=color

# %%
propery_dict=colours_dict
propery_dict
# Out:
# {'Apple': '',
#  'Banana': '',
#  'Bean': '',
#  'Beetroot': '',
#  'Bitter gourd': '',
#  'Bottle gourd': '',
#  'Brinjal': '',
#  'Broccoli': '',
#  'Cabbage': '',
#  'Capsicum': '',
#  'Carrot': '',
#  'Cauliflower': '',
#  'Cucumber': '',
#  'Custard apple': '',
#  'Dragonfruit': '',
#  'Fig': '',
#  'Garlic': '',
#  'Ginger': '',
#  'Grape': '',
#  'Guava': '',
#  'Jackfruit': '',
#  'Kiwi': '',
#  'Lemon': '',
#  'Mango': '',
#  'Mosambi': '',
#  'Muskmelon': '',
#  'Okra': '',
#  'Onion': '',
#  'Orange': '',
#  'Papaya': '',
#  'Pear': '',
#  'Peas': '',
#  'Pineapple': '',
#  'Pomegranate': '',
#  'Potato': '',
#  'Pumpkin': '',
#  'Radish': '',
#  'Sapodilla': '',
#  'Strawberry': '',
#  'Sweet potato': '',
#  'Tomato': '',
#  'Watermelon': ''}

# %%
fruits=['Apple','Banana','Custard apple','Dragonfruit','Fig','Grape','Guava','Jackfruit','Kiwi','Mango','Mosambi','Muskmelon','Orange','Papaya','Pear','Pineapple','Pomegranate','Sapodilla', 'Strawberry','Watermelon']
vegetables=list(set(key_words)-set(fruits))
# vegetables

# %%
first=0
driver = webdriver.Chrome('C:\chromedriver.exe')
driver.get('https://www.google.co.in/imghp?hl=en&authuser=0&ogbl')
total_errors=0
for i in fruits:
    desired_len=50
    first+=1
    folder_name = '..\\..\\final_dataset\\test\\'+i
    if not os.path.isdir(folder_name):
        os.makedirs(folder_name)
    else:
        tmp=os.listdir(folder_name)
        desired_len-=len(tmp)
        
    def download_image(url, folder_name, num):
        # write image to file
        reponse = requests.get(url)
        if reponse.status_code==200:
            with open(os.path.join(folder_name,str(num)+"_z.jpg"), 'wb') as file:
                file.write(reponse.content)
    if(first==1):
        box = driver.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
        box.send_keys(propery_dict[i]+' '+i+' Fruit')
        box.send_keys(Keys.ENTER)
    else:
        box = driver.find_element('xpath','//*[@id="REsRA"]')
        for blah in range(10):
            box.send_keys(Keys.CONTROL+Keys.BACK_SPACE)
        box.send_keys(propery_dict[i]+' '+i+' Fruit')
        box.send_keys(Keys.ENTER)
        

    
    last_height = driver.execute_script('return document.body.scrollHeight')
    counter=0
    while counter<12:
        driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
        time.sleep(2)
        new_height = driver.execute_script('return document.body.scrollHeight')
        try:
            driver.find_element('xpath','//*[@id="islmp"]/div/div/div/div[1]/div[2]/div[2]/input').click()
            counter+=1
            time.sleep(2)
        except:
            
            pass
        if new_height == last_height:
            break
        last_height = new_height

    #Scrolling all the way up
    driver.execute_script("window.scrollTo(0, 0);")
    page_html = driver.page_source
    pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
    containers = pageSoup.findAll('div', {'class':"isv-r PNCib MSM1fd BUooTd"} )
    len_containers = len(containers)
    print("len_containers for ",i," is ",len_containers)
    countersss=0
    for i in range(1, len_containers+1):        
        xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)
        print("For image number: ",i,"Just started")
        try:
            previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
            # print("For image number: ",i,"Found previewImageXpath")
            previewImageElement = driver.find_element('xpath',previewImageXPath)
            previewImageURL = previewImageElement.get_attribute("src")
            driver.find_element('xpath',xPath).click()
        except:
            print("For image number: ",i,"Could Not Find previewImageXpath")
            total_errors+=1
            continue

        timeStarted = time.time()
        # print("For image number: ",i,"Found ImageURL by clicking on that retriving src attribute")
        while True:
            try:              
#               #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img
                #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img
                imageElement = driver.find_element('xpath',"""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img""")
                imageURL= imageElement.get_attribute('src')
                
            
                if imageURL != previewImageURL:
                    #print("actual URL", imageURL)
                    # print("For image number: ",i," previewImageXpath and Image URL donot match")
                    break

                else:
                    # making a timeout if the full res image can't be loaded
                    currentTime = time.time()

                    if currentTime - timeStarted > 10:
        #                     print("Timeout! Will download a lower resolution image and move onto the next one")
                        # print("For image number: ",i,"Timeout")                    
                        break
            except:
                # print("For image number: ",i,"Could not Find ImageXpath")
                break
        


        try:
            download_image(imageURL, folder_name, i)
#             print("Downloaded element %s out of %s total. URL: %s" % (i, len_containers + 1, imageURL))
            print("Downloaded element %s out of %s total."%(i,len_containers+1))
            countersss+=1
            if(countersss>=desired_len):
                print("Exceeded Length Doubt this occurs")
                break
        except:
            total_errors+=1
            print("Couldn't download an image %s, continuing downloading the next one"%(i))
    print("For class ",i," The number of failures are ",total_errors)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_17292\3636773032.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\chromedriver.exe')
# len_containers for  Apple  is  674
# For image number:  1 Just started
# Downloaded element 1 out of 675 total.
# For image number:  2 Just started
# Downloaded element 2 out of 675 total.
# For image number:  3 Just started
# Downloaded element 3 out of 675 total.
# For image number:  4 Just started
# Downloaded element 4 out of 675 total.
# For image number:  5 Just started
# Downloaded element 5 out of 675 total.
# For image number:  6 Just started
# Downloaded element 6 out of 675 total.
# For image number:  7 Just started
# Downloaded element 7 out of 675 total.
# For image number:  8 Just started
# Downloaded element 8 out of 675 total.
# For image number:  9 Just started
# Downloaded element 9 out of 675 total.
# For image number:  10 Just started
# Downloaded element 10 out of 675 total.
# For image number:  11 Just started
# Downloaded element 11 out of 675 total.
# For image number:  12 Just started
# Downloaded element 12 out of 675 total.
# For image number:  13 Just started
# Downloaded element 13 out of 675 total.
# For image number:  14 Just started
# Downloaded element 14 out of 675 total.
# For image number:  15 Just started
# Downloaded element 15 out of 675 total.
# For image number:  16 Just started
# Downloaded element 16 out of 675 total.
# For image number:  17 Just started
# Downloaded element 17 out of 675 total.
# For image number:  18 Just started
# Downloaded element 18 out of 675 total.
# For image number:  19 Just started
# Downloaded element 19 out of 675 total.
# For image number:  20 Just started
# Downloaded element 20 out of 675 total.
# For image number:  21 Just started
# Downloaded element 21 out of 675 total.
# For image number:  22 Just started
# Downloaded element 22 out of 675 total.
# For image number:  23 Just started
# Downloaded element 23 out of 675 total.
# For image number:  24 Just started
# Downloaded element 24 out of 675 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 675 total.
# For image number:  27 Just started
# Downloaded element 27 out of 675 total.
# For image number:  28 Just started
# Downloaded element 28 out of 675 total.
# For image number:  29 Just started
# Downloaded element 29 out of 675 total.
# For image number:  30 Just started
# Downloaded element 30 out of 675 total.
# For image number:  31 Just started
# Downloaded element 31 out of 675 total.
# For image number:  32 Just started
# Downloaded element 32 out of 675 total.
# For image number:  33 Just started
# Downloaded element 33 out of 675 total.
# For image number:  34 Just started
# Downloaded element 34 out of 675 total.
# For image number:  35 Just started
# Downloaded element 35 out of 675 total.
# For image number:  36 Just started
# Downloaded element 36 out of 675 total.
# For image number:  37 Just started
# Downloaded element 37 out of 675 total.
# For image number:  38 Just started
# Downloaded element 38 out of 675 total.
# For image number:  39 Just started
# Downloaded element 39 out of 675 total.
# For image number:  40 Just started
# Downloaded element 40 out of 675 total.
# For image number:  41 Just started
# Downloaded element 41 out of 675 total.
# For image number:  42 Just started
# Downloaded element 42 out of 675 total.
# For image number:  43 Just started
# Downloaded element 43 out of 675 total.
# For image number:  44 Just started
# Downloaded element 44 out of 675 total.
# For image number:  45 Just started
# Downloaded element 45 out of 675 total.
# For image number:  46 Just started
# Downloaded element 46 out of 675 total.
# For image number:  47 Just started
# Downloaded element 47 out of 675 total.
# For image number:  48 Just started
# Downloaded element 48 out of 675 total.
# For image number:  49 Just started
# Downloaded element 49 out of 675 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 675 total.
# For image number:  52 Just started
# Downloaded element 52 out of 675 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  2
# len_containers for  Banana  is  200
# For image number:  1 Just started
# Downloaded element 1 out of 201 total.
# For image number:  2 Just started
# Downloaded element 2 out of 201 total.
# For image number:  3 Just started
# Downloaded element 3 out of 201 total.
# For image number:  4 Just started
# Downloaded element 4 out of 201 total.
# For image number:  5 Just started
# Downloaded element 5 out of 201 total.
# For image number:  6 Just started
# Downloaded element 6 out of 201 total.
# For image number:  7 Just started
# Downloaded element 7 out of 201 total.
# For image number:  8 Just started
# Downloaded element 8 out of 201 total.
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Downloaded element 11 out of 201 total.
# For image number:  12 Just started
# Downloaded element 12 out of 201 total.
# For image number:  13 Just started
# Downloaded element 13 out of 201 total.
# For image number:  14 Just started
# Downloaded element 14 out of 201 total.
# For image number:  15 Just started
# Downloaded element 15 out of 201 total.
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 201 total.
# For image number:  22 Just started
# Downloaded element 22 out of 201 total.
# For image number:  23 Just started
# Downloaded element 23 out of 201 total.
# For image number:  24 Just started
# Downloaded element 24 out of 201 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 201 total.
# For image number:  27 Just started
# Downloaded element 27 out of 201 total.
# For image number:  28 Just started
# Downloaded element 28 out of 201 total.
# For image number:  29 Just started
# Downloaded element 29 out of 201 total.
# For image number:  30 Just started
# Downloaded element 30 out of 201 total.
# For image number:  31 Just started
# Downloaded element 31 out of 201 total.
# For image number:  32 Just started
# Downloaded element 32 out of 201 total.
# For image number:  33 Just started
# Downloaded element 33 out of 201 total.
# For image number:  34 Just started
# Downloaded element 34 out of 201 total.
# For image number:  35 Just started
# Downloaded element 35 out of 201 total.
# For image number:  36 Just started
# Downloaded element 36 out of 201 total.
# For image number:  37 Just started
# Downloaded element 37 out of 201 total.
# For image number:  38 Just started
# Downloaded element 38 out of 201 total.
# For image number:  39 Just started
# Downloaded element 39 out of 201 total.
# For image number:  40 Just started
# Downloaded element 40 out of 201 total.
# For image number:  41 Just started
# Downloaded element 41 out of 201 total.
# For image number:  42 Just started
# Downloaded element 42 out of 201 total.
# For image number:  43 Just started
# Downloaded element 43 out of 201 total.
# For image number:  44 Just started
# Downloaded element 44 out of 201 total.
# For image number:  45 Just started
# Downloaded element 45 out of 201 total.
# For image number:  46 Just started
# Downloaded element 46 out of 201 total.
# For image number:  47 Just started
# Downloaded element 47 out of 201 total.
# For image number:  48 Just started
# Downloaded element 48 out of 201 total.
# For image number:  49 Just started
# Downloaded element 49 out of 201 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 201 total.
# For image number:  52 Just started
# Downloaded element 52 out of 201 total.
# For image number:  53 Just started
# Downloaded element 53 out of 201 total.
# For image number:  54 Just started
# Downloaded element 54 out of 201 total.
# For image number:  55 Just started
# Downloaded element 55 out of 201 total.
# For image number:  56 Just started
# Downloaded element 56 out of 201 total.
# For image number:  57 Just started
# Downloaded element 57 out of 201 total.
# For image number:  58 Just started
# Downloaded element 58 out of 201 total.
# For image number:  59 Just started
# Downloaded element 59 out of 201 total.
# Exceeded Length Doubt this occurs
# For class  59  The number of failures are  11
# len_containers for  Custard apple  is  670
# For image number:  1 Just started
# Downloaded element 1 out of 671 total.
# For image number:  2 Just started
# Downloaded element 2 out of 671 total.
# For image number:  3 Just started
# Downloaded element 3 out of 671 total.
# For image number:  4 Just started
# Downloaded element 4 out of 671 total.
# For image number:  5 Just started
# Downloaded element 5 out of 671 total.
# For image number:  6 Just started
# Downloaded element 6 out of 671 total.
# For image number:  7 Just started
# Downloaded element 7 out of 671 total.
# For image number:  8 Just started
# Downloaded element 8 out of 671 total.
# For image number:  9 Just started
# Downloaded element 9 out of 671 total.
# For image number:  10 Just started
# Downloaded element 10 out of 671 total.
# For image number:  11 Just started
# Downloaded element 11 out of 671 total.
# For image number:  12 Just started
# Downloaded element 12 out of 671 total.
# For image number:  13 Just started
# Downloaded element 13 out of 671 total.
# For image number:  14 Just started
# Downloaded element 14 out of 671 total.
# For image number:  15 Just started
# Downloaded element 15 out of 671 total.
# For image number:  16 Just started
# Downloaded element 16 out of 671 total.
# For image number:  17 Just started
# Downloaded element 17 out of 671 total.
# For image number:  18 Just started
# Downloaded element 18 out of 671 total.
# For image number:  19 Just started
# Downloaded element 19 out of 671 total.
# For image number:  20 Just started
# Downloaded element 20 out of 671 total.
# For image number:  21 Just started
# Downloaded element 21 out of 671 total.
# For image number:  22 Just started
# Downloaded element 22 out of 671 total.
# For image number:  23 Just started
# Downloaded element 23 out of 671 total.
# For image number:  24 Just started
# Downloaded element 24 out of 671 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 671 total.
# For image number:  27 Just started
# Downloaded element 27 out of 671 total.
# For image number:  28 Just started
# Downloaded element 28 out of 671 total.
# For image number:  29 Just started
# Downloaded element 29 out of 671 total.
# For image number:  30 Just started
# Downloaded element 30 out of 671 total.
# For image number:  31 Just started
# Downloaded element 31 out of 671 total.
# For image number:  32 Just started
# Downloaded element 32 out of 671 total.
# For image number:  33 Just started
# Downloaded element 33 out of 671 total.
# For image number:  34 Just started
# Downloaded element 34 out of 671 total.
# For image number:  35 Just started
# Downloaded element 35 out of 671 total.
# For image number:  36 Just started
# Downloaded element 36 out of 671 total.
# For image number:  37 Just started
# Downloaded element 37 out of 671 total.
# For image number:  38 Just started
# Downloaded element 38 out of 671 total.
# For image number:  39 Just started
# Downloaded element 39 out of 671 total.
# For image number:  40 Just started
# Downloaded element 40 out of 671 total.
# For image number:  41 Just started
# Downloaded element 41 out of 671 total.
# For image number:  42 Just started
# Downloaded element 42 out of 671 total.
# For image number:  43 Just started
# Downloaded element 43 out of 671 total.
# For image number:  44 Just started
# Downloaded element 44 out of 671 total.
# For image number:  45 Just started
# Downloaded element 45 out of 671 total.
# For image number:  46 Just started
# Downloaded element 46 out of 671 total.
# For image number:  47 Just started
# Downloaded element 47 out of 671 total.
# For image number:  48 Just started
# Downloaded element 48 out of 671 total.
# For image number:  49 Just started
# Downloaded element 49 out of 671 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 671 total.
# For image number:  52 Just started
# Downloaded element 52 out of 671 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  13
# len_containers for  Dragonfruit  is  768
# For image number:  1 Just started
# Downloaded element 1 out of 769 total.
# For image number:  2 Just started
# Downloaded element 2 out of 769 total.
# For image number:  3 Just started
# Downloaded element 3 out of 769 total.
# For image number:  4 Just started
# Downloaded element 4 out of 769 total.
# For image number:  5 Just started
# Downloaded element 5 out of 769 total.
# For image number:  6 Just started
# Downloaded element 6 out of 769 total.
# For image number:  7 Just started
# Downloaded element 7 out of 769 total.
# For image number:  8 Just started
# Downloaded element 8 out of 769 total.
# For image number:  9 Just started
# Downloaded element 9 out of 769 total.
# For image number:  10 Just started
# Downloaded element 10 out of 769 total.
# For image number:  11 Just started
# Downloaded element 11 out of 769 total.
# For image number:  12 Just started
# Downloaded element 12 out of 769 total.
# For image number:  13 Just started
# Downloaded element 13 out of 769 total.
# For image number:  14 Just started
# Downloaded element 14 out of 769 total.
# For image number:  15 Just started
# Downloaded element 15 out of 769 total.
# For image number:  16 Just started
# Downloaded element 16 out of 769 total.
# For image number:  17 Just started
# Downloaded element 17 out of 769 total.
# For image number:  18 Just started
# Downloaded element 18 out of 769 total.
# For image number:  19 Just started
# Downloaded element 19 out of 769 total.
# For image number:  20 Just started
# Downloaded element 20 out of 769 total.
# For image number:  21 Just started
# Downloaded element 21 out of 769 total.
# For image number:  22 Just started
# Downloaded element 22 out of 769 total.
# For image number:  23 Just started
# Downloaded element 23 out of 769 total.
# For image number:  24 Just started
# Downloaded element 24 out of 769 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 769 total.
# For image number:  27 Just started
# Downloaded element 27 out of 769 total.
# For image number:  28 Just started
# Downloaded element 28 out of 769 total.
# For image number:  29 Just started
# Downloaded element 29 out of 769 total.
# For image number:  30 Just started
# Downloaded element 30 out of 769 total.
# For image number:  31 Just started
# Downloaded element 31 out of 769 total.
# For image number:  32 Just started
# Downloaded element 32 out of 769 total.
# For image number:  33 Just started
# Downloaded element 33 out of 769 total.
# For image number:  34 Just started
# Downloaded element 34 out of 769 total.
# For image number:  35 Just started
# Downloaded element 35 out of 769 total.
# For image number:  36 Just started
# Downloaded element 36 out of 769 total.
# For image number:  37 Just started
# Downloaded element 37 out of 769 total.
# For image number:  38 Just started
# Downloaded element 38 out of 769 total.
# For image number:  39 Just started
# Downloaded element 39 out of 769 total.
# For image number:  40 Just started
# Downloaded element 40 out of 769 total.
# For image number:  41 Just started
# Downloaded element 41 out of 769 total.
# For image number:  42 Just started
# Downloaded element 42 out of 769 total.
# For image number:  43 Just started
# Downloaded element 43 out of 769 total.
# For image number:  44 Just started
# Downloaded element 44 out of 769 total.
# For image number:  45 Just started
# Downloaded element 45 out of 769 total.
# For image number:  46 Just started
# Downloaded element 46 out of 769 total.
# For image number:  47 Just started
# Downloaded element 47 out of 769 total.
# For image number:  48 Just started
# Downloaded element 48 out of 769 total.
# For image number:  49 Just started
# Downloaded element 49 out of 769 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 769 total.
# For image number:  52 Just started
# Downloaded element 52 out of 769 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  15
# len_containers for  Fig  is  928
# For image number:  1 Just started
# Downloaded element 1 out of 929 total.
# For image number:  2 Just started
# Downloaded element 2 out of 929 total.
# For image number:  3 Just started
# Downloaded element 3 out of 929 total.
# For image number:  4 Just started
# Downloaded element 4 out of 929 total.
# For image number:  5 Just started
# Downloaded element 5 out of 929 total.
# For image number:  6 Just started
# Downloaded element 6 out of 929 total.
# For image number:  7 Just started
# Downloaded element 7 out of 929 total.
# For image number:  8 Just started
# Downloaded element 8 out of 929 total.
# For image number:  9 Just started
# Downloaded element 9 out of 929 total.
# For image number:  10 Just started
# Downloaded element 10 out of 929 total.
# For image number:  11 Just started
# Downloaded element 11 out of 929 total.
# For image number:  12 Just started
# Downloaded element 12 out of 929 total.
# For image number:  13 Just started
# Downloaded element 13 out of 929 total.
# For image number:  14 Just started
# Downloaded element 14 out of 929 total.
# For image number:  15 Just started
# Downloaded element 15 out of 929 total.
# For image number:  16 Just started
# Downloaded element 16 out of 929 total.
# For image number:  17 Just started
# Downloaded element 17 out of 929 total.
# For image number:  18 Just started
# Downloaded element 18 out of 929 total.
# For image number:  19 Just started
# Downloaded element 19 out of 929 total.
# For image number:  20 Just started
# Downloaded element 20 out of 929 total.
# For image number:  21 Just started
# Downloaded element 21 out of 929 total.
# For image number:  22 Just started
# Downloaded element 22 out of 929 total.
# For image number:  23 Just started
# Downloaded element 23 out of 929 total.
# For image number:  24 Just started
# Downloaded element 24 out of 929 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 929 total.
# For image number:  27 Just started
# Downloaded element 27 out of 929 total.
# For image number:  28 Just started
# Downloaded element 28 out of 929 total.
# For image number:  29 Just started
# Downloaded element 29 out of 929 total.
# For image number:  30 Just started
# Downloaded element 30 out of 929 total.
# For image number:  31 Just started
# Downloaded element 31 out of 929 total.
# For image number:  32 Just started
# Downloaded element 32 out of 929 total.
# For image number:  33 Just started
# Downloaded element 33 out of 929 total.
# For image number:  34 Just started
# Downloaded element 34 out of 929 total.
# For image number:  35 Just started
# Downloaded element 35 out of 929 total.
# For image number:  36 Just started
# Downloaded element 36 out of 929 total.
# For image number:  37 Just started
# Downloaded element 37 out of 929 total.
# For image number:  38 Just started
# Downloaded element 38 out of 929 total.
# For image number:  39 Just started
# Downloaded element 39 out of 929 total.
# For image number:  40 Just started
# Downloaded element 40 out of 929 total.
# For image number:  41 Just started
# Downloaded element 41 out of 929 total.
# For image number:  42 Just started
# Downloaded element 42 out of 929 total.
# For image number:  43 Just started
# Downloaded element 43 out of 929 total.
# For image number:  44 Just started
# Downloaded element 44 out of 929 total.
# For image number:  45 Just started
# Downloaded element 45 out of 929 total.
# For image number:  46 Just started
# Downloaded element 46 out of 929 total.
# For image number:  47 Just started
# Downloaded element 47 out of 929 total.
# For image number:  48 Just started
# Downloaded element 48 out of 929 total.
# For image number:  49 Just started
# Downloaded element 49 out of 929 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 929 total.
# For image number:  52 Just started
# Downloaded element 52 out of 929 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  17
# len_containers for  Grape  is  630
# For image number:  1 Just started
# Downloaded element 1 out of 631 total.
# For image number:  2 Just started
# Downloaded element 2 out of 631 total.
# For image number:  3 Just started
# Downloaded element 3 out of 631 total.
# For image number:  4 Just started
# Downloaded element 4 out of 631 total.
# For image number:  5 Just started
# Downloaded element 5 out of 631 total.
# For image number:  6 Just started
# Downloaded element 6 out of 631 total.
# For image number:  7 Just started
# Downloaded element 7 out of 631 total.
# For image number:  8 Just started
# Downloaded element 8 out of 631 total.
# For image number:  9 Just started
# Downloaded element 9 out of 631 total.
# For image number:  10 Just started
# Downloaded element 10 out of 631 total.
# For image number:  11 Just started
# Downloaded element 11 out of 631 total.
# For image number:  12 Just started
# Downloaded element 12 out of 631 total.
# For image number:  13 Just started
# Downloaded element 13 out of 631 total.
# For image number:  14 Just started
# Downloaded element 14 out of 631 total.
# For image number:  15 Just started
# Downloaded element 15 out of 631 total.
# For image number:  16 Just started
# Downloaded element 16 out of 631 total.
# For image number:  17 Just started
# Downloaded element 17 out of 631 total.
# For image number:  18 Just started
# Downloaded element 18 out of 631 total.
# For image number:  19 Just started
# Downloaded element 19 out of 631 total.
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 631 total.
# For image number:  22 Just started
# Downloaded element 22 out of 631 total.
# For image number:  23 Just started
# Downloaded element 23 out of 631 total.
# For image number:  24 Just started
# Downloaded element 24 out of 631 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 631 total.
# For image number:  27 Just started
# Downloaded element 27 out of 631 total.
# For image number:  28 Just started
# Downloaded element 28 out of 631 total.
# For image number:  29 Just started
# Downloaded element 29 out of 631 total.
# For image number:  30 Just started
# Downloaded element 30 out of 631 total.
# For image number:  31 Just started
# Downloaded element 31 out of 631 total.
# For image number:  32 Just started
# Downloaded element 32 out of 631 total.
# For image number:  33 Just started
# Downloaded element 33 out of 631 total.
# For image number:  34 Just started
# Downloaded element 34 out of 631 total.
# For image number:  35 Just started
# Downloaded element 35 out of 631 total.
# For image number:  36 Just started
# Downloaded element 36 out of 631 total.
# For image number:  37 Just started
# Downloaded element 37 out of 631 total.
# For image number:  38 Just started
# Downloaded element 38 out of 631 total.
# For image number:  39 Just started
# Downloaded element 39 out of 631 total.
# For image number:  40 Just started
# Downloaded element 40 out of 631 total.
# For image number:  41 Just started
# Downloaded element 41 out of 631 total.
# For image number:  42 Just started
# Downloaded element 42 out of 631 total.
# For image number:  43 Just started
# Downloaded element 43 out of 631 total.
# For image number:  44 Just started
# Downloaded element 44 out of 631 total.
# For image number:  45 Just started
# Downloaded element 45 out of 631 total.
# For image number:  46 Just started
# Downloaded element 46 out of 631 total.
# For image number:  47 Just started
# Downloaded element 47 out of 631 total.
# For image number:  48 Just started
# Downloaded element 48 out of 631 total.
# For image number:  49 Just started
# Downloaded element 49 out of 631 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 631 total.
# For image number:  52 Just started
# Downloaded element 52 out of 631 total.
# For image number:  53 Just started
# Downloaded element 53 out of 631 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  20
# len_containers for  Guava  is  827
# For image number:  1 Just started
# Downloaded element 1 out of 828 total.
# For image number:  2 Just started
# Downloaded element 2 out of 828 total.
# For image number:  3 Just started
# Downloaded element 3 out of 828 total.
# For image number:  4 Just started
# Downloaded element 4 out of 828 total.
# For image number:  5 Just started
# Downloaded element 5 out of 828 total.
# For image number:  6 Just started
# Downloaded element 6 out of 828 total.
# For image number:  7 Just started
# Downloaded element 7 out of 828 total.
# For image number:  8 Just started
# Downloaded element 8 out of 828 total.
# For image number:  9 Just started
# Downloaded element 9 out of 828 total.
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Downloaded element 11 out of 828 total.
# For image number:  12 Just started
# Downloaded element 12 out of 828 total.
# For image number:  13 Just started
# Downloaded element 13 out of 828 total.
# For image number:  14 Just started
# Downloaded element 14 out of 828 total.
# For image number:  15 Just started
# Downloaded element 15 out of 828 total.
# For image number:  16 Just started
# Downloaded element 16 out of 828 total.
# For image number:  17 Just started
# Downloaded element 17 out of 828 total.
# For image number:  18 Just started
# Downloaded element 18 out of 828 total.
# For image number:  19 Just started
# Downloaded element 19 out of 828 total.
# For image number:  20 Just started
# Downloaded element 20 out of 828 total.
# For image number:  21 Just started
# Downloaded element 21 out of 828 total.
# For image number:  22 Just started
# Downloaded element 22 out of 828 total.
# For image number:  23 Just started
# Downloaded element 23 out of 828 total.
# For image number:  24 Just started
# Downloaded element 24 out of 828 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 828 total.
# For image number:  27 Just started
# Downloaded element 27 out of 828 total.
# For image number:  28 Just started
# Downloaded element 28 out of 828 total.
# For image number:  29 Just started
# Downloaded element 29 out of 828 total.
# For image number:  30 Just started
# Downloaded element 30 out of 828 total.
# For image number:  31 Just started
# Downloaded element 31 out of 828 total.
# For image number:  32 Just started
# Downloaded element 32 out of 828 total.
# For image number:  33 Just started
# Downloaded element 33 out of 828 total.
# For image number:  34 Just started
# Downloaded element 34 out of 828 total.
# For image number:  35 Just started
# Downloaded element 35 out of 828 total.
# For image number:  36 Just started
# Downloaded element 36 out of 828 total.
# For image number:  37 Just started
# Downloaded element 37 out of 828 total.
# For image number:  38 Just started
# Downloaded element 38 out of 828 total.
# For image number:  39 Just started
# Downloaded element 39 out of 828 total.
# For image number:  40 Just started
# Downloaded element 40 out of 828 total.
# For image number:  41 Just started
# Downloaded element 41 out of 828 total.
# For image number:  42 Just started
# Downloaded element 42 out of 828 total.
# For image number:  43 Just started
# Downloaded element 43 out of 828 total.
# For image number:  44 Just started
# Downloaded element 44 out of 828 total.
# For image number:  45 Just started
# Downloaded element 45 out of 828 total.
# For image number:  46 Just started
# Downloaded element 46 out of 828 total.
# For image number:  47 Just started
# Downloaded element 47 out of 828 total.
# For image number:  48 Just started
# Downloaded element 48 out of 828 total.
# For image number:  49 Just started
# Downloaded element 49 out of 828 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 828 total.
# For image number:  52 Just started
# Downloaded element 52 out of 828 total.
# For image number:  53 Just started
# Downloaded element 53 out of 828 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  23
# len_containers for  Jackfruit  is  783
# For image number:  1 Just started
# Downloaded element 1 out of 784 total.
# For image number:  2 Just started
# Downloaded element 2 out of 784 total.
# For image number:  3 Just started
# Downloaded element 3 out of 784 total.
# For image number:  4 Just started
# Downloaded element 4 out of 784 total.
# For image number:  5 Just started
# Downloaded element 5 out of 784 total.
# For image number:  6 Just started
# Downloaded element 6 out of 784 total.
# For image number:  7 Just started
# Downloaded element 7 out of 784 total.
# For image number:  8 Just started
# Downloaded element 8 out of 784 total.
# For image number:  9 Just started
# Downloaded element 9 out of 784 total.
# For image number:  10 Just started
# Downloaded element 10 out of 784 total.
# For image number:  11 Just started
# Downloaded element 11 out of 784 total.
# For image number:  12 Just started
# Downloaded element 12 out of 784 total.
# For image number:  13 Just started
# Downloaded element 13 out of 784 total.
# For image number:  14 Just started
# Downloaded element 14 out of 784 total.
# For image number:  15 Just started
# Downloaded element 15 out of 784 total.
# For image number:  16 Just started
# Downloaded element 16 out of 784 total.
# For image number:  17 Just started
# Downloaded element 17 out of 784 total.
# For image number:  18 Just started
# Downloaded element 18 out of 784 total.
# For image number:  19 Just started
# Downloaded element 19 out of 784 total.
# For image number:  20 Just started
# Downloaded element 20 out of 784 total.
# For image number:  21 Just started
# Downloaded element 21 out of 784 total.
# For image number:  22 Just started
# Downloaded element 22 out of 784 total.
# For image number:  23 Just started
# Downloaded element 23 out of 784 total.
# For image number:  24 Just started
# Downloaded element 24 out of 784 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 784 total.
# For image number:  27 Just started
# Downloaded element 27 out of 784 total.
# For image number:  28 Just started
# Downloaded element 28 out of 784 total.
# For image number:  29 Just started
# Downloaded element 29 out of 784 total.
# For image number:  30 Just started
# Downloaded element 30 out of 784 total.
# For image number:  31 Just started
# Downloaded element 31 out of 784 total.
# For image number:  32 Just started
# Downloaded element 32 out of 784 total.
# For image number:  33 Just started
# Downloaded element 33 out of 784 total.
# For image number:  34 Just started
# Downloaded element 34 out of 784 total.
# For image number:  35 Just started
# Downloaded element 35 out of 784 total.
# For image number:  36 Just started
# Downloaded element 36 out of 784 total.
# For image number:  37 Just started
# Downloaded element 37 out of 784 total.
# For image number:  38 Just started
# Downloaded element 38 out of 784 total.
# For image number:  39 Just started
# Downloaded element 39 out of 784 total.
# For image number:  40 Just started
# Downloaded element 40 out of 784 total.
# For image number:  41 Just started
# Downloaded element 41 out of 784 total.
# For image number:  42 Just started
# Downloaded element 42 out of 784 total.
# For image number:  43 Just started
# Downloaded element 43 out of 784 total.
# For image number:  44 Just started
# Downloaded element 44 out of 784 total.
# For image number:  45 Just started
# Downloaded element 45 out of 784 total.
# For image number:  46 Just started
# Downloaded element 46 out of 784 total.
# For image number:  47 Just started
# Downloaded element 47 out of 784 total.
# For image number:  48 Just started
# Downloaded element 48 out of 784 total.
# For image number:  49 Just started
# Downloaded element 49 out of 784 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 784 total.
# For image number:  52 Just started
# Downloaded element 52 out of 784 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  25
# len_containers for  Kiwi  is  590
# For image number:  1 Just started
# Downloaded element 1 out of 591 total.
# For image number:  2 Just started
# Downloaded element 2 out of 591 total.
# For image number:  3 Just started
# Downloaded element 3 out of 591 total.
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Downloaded element 5 out of 591 total.
# For image number:  6 Just started
# Downloaded element 6 out of 591 total.
# For image number:  7 Just started
# Downloaded element 7 out of 591 total.
# For image number:  8 Just started
# Downloaded element 8 out of 591 total.
# For image number:  9 Just started
# Downloaded element 9 out of 591 total.
# For image number:  10 Just started
# Downloaded element 10 out of 591 total.
# For image number:  11 Just started
# Downloaded element 11 out of 591 total.
# For image number:  12 Just started
# Downloaded element 12 out of 591 total.
# For image number:  13 Just started
# Downloaded element 13 out of 591 total.
# For image number:  14 Just started
# Downloaded element 14 out of 591 total.
# For image number:  15 Just started
# Downloaded element 15 out of 591 total.
# For image number:  16 Just started
# Downloaded element 16 out of 591 total.
# For image number:  17 Just started
# Downloaded element 17 out of 591 total.
# For image number:  18 Just started
# Downloaded element 18 out of 591 total.
# For image number:  19 Just started
# Downloaded element 19 out of 591 total.
# For image number:  20 Just started
# Downloaded element 20 out of 591 total.
# For image number:  21 Just started
# Downloaded element 21 out of 591 total.
# For image number:  22 Just started
# Downloaded element 22 out of 591 total.
# For image number:  23 Just started
# Downloaded element 23 out of 591 total.
# For image number:  24 Just started
# Downloaded element 24 out of 591 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 591 total.
# For image number:  27 Just started
# Downloaded element 27 out of 591 total.
# For image number:  28 Just started
# Downloaded element 28 out of 591 total.
# For image number:  29 Just started
# Downloaded element 29 out of 591 total.
# For image number:  30 Just started
# Downloaded element 30 out of 591 total.
# For image number:  31 Just started
# Downloaded element 31 out of 591 total.
# For image number:  32 Just started
# Downloaded element 32 out of 591 total.
# For image number:  33 Just started
# Downloaded element 33 out of 591 total.
# For image number:  34 Just started
# Downloaded element 34 out of 591 total.
# For image number:  35 Just started
# Downloaded element 35 out of 591 total.
# For image number:  36 Just started
# Downloaded element 36 out of 591 total.
# For image number:  37 Just started
# Downloaded element 37 out of 591 total.
# For image number:  38 Just started
# Downloaded element 38 out of 591 total.
# For image number:  39 Just started
# Downloaded element 39 out of 591 total.
# For image number:  40 Just started
# Downloaded element 40 out of 591 total.
# For image number:  41 Just started
# Downloaded element 41 out of 591 total.
# For image number:  42 Just started
# Downloaded element 42 out of 591 total.
# For image number:  43 Just started
# Downloaded element 43 out of 591 total.
# For image number:  44 Just started
# Downloaded element 44 out of 591 total.
# For image number:  45 Just started
# Downloaded element 45 out of 591 total.
# For image number:  46 Just started
# Downloaded element 46 out of 591 total.
# For image number:  47 Just started
# Downloaded element 47 out of 591 total.
# For image number:  48 Just started
# Downloaded element 48 out of 591 total.
# For image number:  49 Just started
# Downloaded element 49 out of 591 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 591 total.
# For image number:  52 Just started
# Downloaded element 52 out of 591 total.
# For image number:  53 Just started
# Downloaded element 53 out of 591 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  28
# len_containers for  Mango  is  830
# For image number:  1 Just started
# Downloaded element 1 out of 831 total.
# For image number:  2 Just started
# Downloaded element 2 out of 831 total.
# For image number:  3 Just started
# Downloaded element 3 out of 831 total.
# For image number:  4 Just started
# Downloaded element 4 out of 831 total.
# For image number:  5 Just started
# Downloaded element 5 out of 831 total.
# For image number:  6 Just started
# Downloaded element 6 out of 831 total.
# For image number:  7 Just started
# Downloaded element 7 out of 831 total.
# For image number:  8 Just started
# Downloaded element 8 out of 831 total.
# For image number:  9 Just started
# Downloaded element 9 out of 831 total.
# For image number:  10 Just started
# Downloaded element 10 out of 831 total.
# For image number:  11 Just started
# Downloaded element 11 out of 831 total.
# For image number:  12 Just started
# Downloaded element 12 out of 831 total.
# For image number:  13 Just started
# Downloaded element 13 out of 831 total.
# For image number:  14 Just started
# Downloaded element 14 out of 831 total.
# For image number:  15 Just started
# Downloaded element 15 out of 831 total.
# For image number:  16 Just started
# Downloaded element 16 out of 831 total.
# For image number:  17 Just started
# Downloaded element 17 out of 831 total.
# For image number:  18 Just started
# Downloaded element 18 out of 831 total.
# For image number:  19 Just started
# Downloaded element 19 out of 831 total.
# For image number:  20 Just started
# Downloaded element 20 out of 831 total.
# For image number:  21 Just started
# Downloaded element 21 out of 831 total.
# For image number:  22 Just started
# Downloaded element 22 out of 831 total.
# For image number:  23 Just started
# Downloaded element 23 out of 831 total.
# For image number:  24 Just started
# Downloaded element 24 out of 831 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 831 total.
# For image number:  27 Just started
# Downloaded element 27 out of 831 total.
# For image number:  28 Just started
# Downloaded element 28 out of 831 total.
# For image number:  29 Just started
# Downloaded element 29 out of 831 total.
# For image number:  30 Just started
# Downloaded element 30 out of 831 total.
# For image number:  31 Just started
# Downloaded element 31 out of 831 total.
# For image number:  32 Just started
# Downloaded element 32 out of 831 total.
# For image number:  33 Just started
# Downloaded element 33 out of 831 total.
# For image number:  34 Just started
# Downloaded element 34 out of 831 total.
# For image number:  35 Just started
# Downloaded element 35 out of 831 total.
# For image number:  36 Just started
# Downloaded element 36 out of 831 total.
# For image number:  37 Just started
# Downloaded element 37 out of 831 total.
# For image number:  38 Just started
# Downloaded element 38 out of 831 total.
# For image number:  39 Just started
# Downloaded element 39 out of 831 total.
# For image number:  40 Just started
# Downloaded element 40 out of 831 total.
# For image number:  41 Just started
# Downloaded element 41 out of 831 total.
# For image number:  42 Just started
# Downloaded element 42 out of 831 total.
# For image number:  43 Just started
# Downloaded element 43 out of 831 total.
# For image number:  44 Just started
# Downloaded element 44 out of 831 total.
# For image number:  45 Just started
# Downloaded element 45 out of 831 total.
# For image number:  46 Just started
# Downloaded element 46 out of 831 total.
# For image number:  47 Just started
# Downloaded element 47 out of 831 total.
# For image number:  48 Just started
# Downloaded element 48 out of 831 total.
# For image number:  49 Just started
# Downloaded element 49 out of 831 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 831 total.
# For image number:  52 Just started
# Downloaded element 52 out of 831 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  30
# len_containers for  Mosambi  is  575
# For image number:  1 Just started
# Downloaded element 1 out of 576 total.
# For image number:  2 Just started
# Downloaded element 2 out of 576 total.
# For image number:  3 Just started
# Downloaded element 3 out of 576 total.
# For image number:  4 Just started
# Downloaded element 4 out of 576 total.
# For image number:  5 Just started
# Downloaded element 5 out of 576 total.
# For image number:  6 Just started
# Downloaded element 6 out of 576 total.
# For image number:  7 Just started
# Downloaded element 7 out of 576 total.
# For image number:  8 Just started
# Downloaded element 8 out of 576 total.
# For image number:  9 Just started
# Downloaded element 9 out of 576 total.
# For image number:  10 Just started
# Downloaded element 10 out of 576 total.
# For image number:  11 Just started
# Downloaded element 11 out of 576 total.
# For image number:  12 Just started
# Downloaded element 12 out of 576 total.
# For image number:  13 Just started
# Downloaded element 13 out of 576 total.
# For image number:  14 Just started
# Downloaded element 14 out of 576 total.
# For image number:  15 Just started
# Downloaded element 15 out of 576 total.
# For image number:  16 Just started
# Downloaded element 16 out of 576 total.
# For image number:  17 Just started
# Downloaded element 17 out of 576 total.
# For image number:  18 Just started
# Downloaded element 18 out of 576 total.
# For image number:  19 Just started
# Downloaded element 19 out of 576 total.
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 576 total.
# For image number:  22 Just started
# Downloaded element 22 out of 576 total.
# For image number:  23 Just started
# Downloaded element 23 out of 576 total.
# For image number:  24 Just started
# Downloaded element 24 out of 576 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 576 total.
# For image number:  27 Just started
# Downloaded element 27 out of 576 total.
# For image number:  28 Just started
# Downloaded element 28 out of 576 total.
# For image number:  29 Just started
# Downloaded element 29 out of 576 total.
# For image number:  30 Just started
# Downloaded element 30 out of 576 total.
# For image number:  31 Just started
# Downloaded element 31 out of 576 total.
# For image number:  32 Just started
# Downloaded element 32 out of 576 total.
# For image number:  33 Just started
# Downloaded element 33 out of 576 total.
# For image number:  34 Just started
# Downloaded element 34 out of 576 total.
# For image number:  35 Just started
# Downloaded element 35 out of 576 total.
# For image number:  36 Just started
# Downloaded element 36 out of 576 total.
# For image number:  37 Just started
# Downloaded element 37 out of 576 total.
# For image number:  38 Just started
# Downloaded element 38 out of 576 total.
# For image number:  39 Just started
# Downloaded element 39 out of 576 total.
# For image number:  40 Just started
# Downloaded element 40 out of 576 total.
# For image number:  41 Just started
# Downloaded element 41 out of 576 total.
# For image number:  42 Just started
# Downloaded element 42 out of 576 total.
# For image number:  43 Just started
# Downloaded element 43 out of 576 total.
# For image number:  44 Just started
# Downloaded element 44 out of 576 total.
# For image number:  45 Just started
# Downloaded element 45 out of 576 total.
# For image number:  46 Just started
# Downloaded element 46 out of 576 total.
# For image number:  47 Just started
# Downloaded element 47 out of 576 total.
# For image number:  48 Just started
# Downloaded element 48 out of 576 total.
# For image number:  49 Just started
# Downloaded element 49 out of 576 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 576 total.
# For image number:  52 Just started
# Downloaded element 52 out of 576 total.
# For image number:  53 Just started
# Downloaded element 53 out of 576 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  33
# len_containers for  Muskmelon  is  774
# For image number:  1 Just started
# Downloaded element 1 out of 775 total.
# For image number:  2 Just started
# Downloaded element 2 out of 775 total.
# For image number:  3 Just started
# Downloaded element 3 out of 775 total.
# For image number:  4 Just started
# Downloaded element 4 out of 775 total.
# For image number:  5 Just started
# Downloaded element 5 out of 775 total.
# For image number:  6 Just started
# Downloaded element 6 out of 775 total.
# For image number:  7 Just started
# Downloaded element 7 out of 775 total.
# For image number:  8 Just started
# Downloaded element 8 out of 775 total.
# For image number:  9 Just started
# Downloaded element 9 out of 775 total.
# For image number:  10 Just started
# Downloaded element 10 out of 775 total.
# For image number:  11 Just started
# Downloaded element 11 out of 775 total.
# For image number:  12 Just started
# Downloaded element 12 out of 775 total.
# For image number:  13 Just started
# Downloaded element 13 out of 775 total.
# For image number:  14 Just started
# Downloaded element 14 out of 775 total.
# For image number:  15 Just started
# Downloaded element 15 out of 775 total.
# For image number:  16 Just started
# Downloaded element 16 out of 775 total.
# For image number:  17 Just started
# Downloaded element 17 out of 775 total.
# For image number:  18 Just started
# Downloaded element 18 out of 775 total.
# For image number:  19 Just started
# Downloaded element 19 out of 775 total.
# For image number:  20 Just started
# Downloaded element 20 out of 775 total.
# For image number:  21 Just started
# Downloaded element 21 out of 775 total.
# For image number:  22 Just started
# Downloaded element 22 out of 775 total.
# For image number:  23 Just started
# Downloaded element 23 out of 775 total.
# For image number:  24 Just started
# Downloaded element 24 out of 775 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 775 total.
# For image number:  27 Just started
# Downloaded element 27 out of 775 total.
# For image number:  28 Just started
# Downloaded element 28 out of 775 total.
# For image number:  29 Just started
# Downloaded element 29 out of 775 total.
# For image number:  30 Just started
# Downloaded element 30 out of 775 total.
# For image number:  31 Just started
# ...
# Downloaded element 3 out of 49 total.
# For image number:  4 Just started
# Downloaded element 4 out of 49 total.
# For image number:  5 Just started
# Downloaded element 5 out of 49 total.
# For image number:  6 Just started
# Downloaded element 6 out of 49 total.
# For image number:  7 Just started
# Downloaded element 7 out of 49 total.
# For image number:  8 Just started
# Downloaded element 8 out of 49 total.
# For image number:  9 Just started
# Downloaded element 9 out of 49 total.
# For image number:  10 Just started
# Downloaded element 10 out of 49 total.
# For image number:  11 Just started
# Downloaded element 11 out of 49 total.
# For image number:  12 Just started
# Downloaded element 12 out of 49 total.
# For image number:  13 Just started
# Downloaded element 13 out of 49 total.
# For image number:  14 Just started
# Downloaded element 14 out of 49 total.
# For image number:  15 Just started
# Downloaded element 15 out of 49 total.
# For image number:  16 Just started
# Downloaded element 16 out of 49 total.
# For image number:  17 Just started
# Downloaded element 17 out of 49 total.
# For image number:  18 Just started
# Downloaded element 18 out of 49 total.
# For image number:  19 Just started
# Downloaded element 19 out of 49 total.
# For image number:  20 Just started
# Downloaded element 20 out of 49 total.
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  79
# len_containers for  Sapodilla  is  608
# For image number:  1 Just started
# Downloaded element 1 out of 609 total.
# For image number:  2 Just started
# Downloaded element 2 out of 609 total.
# For image number:  3 Just started
# Downloaded element 3 out of 609 total.
# For image number:  4 Just started
# Downloaded element 4 out of 609 total.
# For image number:  5 Just started
# Downloaded element 5 out of 609 total.
# For image number:  6 Just started
# Downloaded element 6 out of 609 total.
# For image number:  7 Just started
# Downloaded element 7 out of 609 total.
# For image number:  8 Just started
# Downloaded element 8 out of 609 total.
# For image number:  9 Just started
# Downloaded element 9 out of 609 total.
# For image number:  10 Just started
# Downloaded element 10 out of 609 total.
# For image number:  11 Just started
# Downloaded element 11 out of 609 total.
# For image number:  12 Just started
# Downloaded element 12 out of 609 total.
# For image number:  13 Just started
# Downloaded element 13 out of 609 total.
# For image number:  14 Just started
# Downloaded element 14 out of 609 total.
# For image number:  15 Just started
# Downloaded element 15 out of 609 total.
# For image number:  16 Just started
# Downloaded element 16 out of 609 total.
# For image number:  17 Just started
# Downloaded element 17 out of 609 total.
# For image number:  18 Just started
# Downloaded element 18 out of 609 total.
# For image number:  19 Just started
# Downloaded element 19 out of 609 total.
# For image number:  20 Just started
# Downloaded element 20 out of 609 total.
# For image number:  21 Just started
# Downloaded element 21 out of 609 total.
# For image number:  22 Just started
# Downloaded element 22 out of 609 total.
# For image number:  23 Just started
# Downloaded element 23 out of 609 total.
# For image number:  24 Just started
# Downloaded element 24 out of 609 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 609 total.
# For image number:  27 Just started
# Downloaded element 27 out of 609 total.
# For image number:  28 Just started
# Downloaded element 28 out of 609 total.
# For image number:  29 Just started
# Downloaded element 29 out of 609 total.
# For image number:  30 Just started
# Downloaded element 30 out of 609 total.
# For image number:  31 Just started
# Downloaded element 31 out of 609 total.
# For image number:  32 Just started
# Downloaded element 32 out of 609 total.
# For image number:  33 Just started
# Downloaded element 33 out of 609 total.
# For image number:  34 Just started
# Downloaded element 34 out of 609 total.
# For image number:  35 Just started
# Downloaded element 35 out of 609 total.
# For image number:  36 Just started
# Downloaded element 36 out of 609 total.
# For image number:  37 Just started
# Downloaded element 37 out of 609 total.
# For image number:  38 Just started
# Downloaded element 38 out of 609 total.
# For image number:  39 Just started
# Downloaded element 39 out of 609 total.
# For image number:  40 Just started
# Downloaded element 40 out of 609 total.
# For image number:  41 Just started
# Downloaded element 41 out of 609 total.
# For image number:  42 Just started
# Downloaded element 42 out of 609 total.
# For image number:  43 Just started
# Downloaded element 43 out of 609 total.
# For image number:  44 Just started
# Downloaded element 44 out of 609 total.
# For image number:  45 Just started
# Downloaded element 45 out of 609 total.
# For image number:  46 Just started
# Downloaded element 46 out of 609 total.
# For image number:  47 Just started
# Downloaded element 47 out of 609 total.
# For image number:  48 Just started
# Downloaded element 48 out of 609 total.
# For image number:  49 Just started
# Downloaded element 49 out of 609 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 609 total.
# For image number:  52 Just started
# Downloaded element 52 out of 609 total.
# Exceeded Length Doubt this occurs
# For class  52  The number of failures are  81
# len_containers for  Strawberry  is  676
# For image number:  1 Just started
# Downloaded element 1 out of 677 total.
# For image number:  2 Just started
# Downloaded element 2 out of 677 total.
# For image number:  3 Just started
# Downloaded element 3 out of 677 total.
# For image number:  4 Just started
# Downloaded element 4 out of 677 total.
# For image number:  5 Just started
# Downloaded element 5 out of 677 total.
# For image number:  6 Just started
# Downloaded element 6 out of 677 total.
# For image number:  7 Just started
# Downloaded element 7 out of 677 total.
# For image number:  8 Just started
# Downloaded element 8 out of 677 total.
# For image number:  9 Just started
# Downloaded element 9 out of 677 total.
# For image number:  10 Just started
# Downloaded element 10 out of 677 total.
# For image number:  11 Just started
# Downloaded element 11 out of 677 total.
# For image number:  12 Just started
# Downloaded element 12 out of 677 total.
# For image number:  13 Just started
# Downloaded element 13 out of 677 total.
# For image number:  14 Just started
# Downloaded element 14 out of 677 total.
# For image number:  15 Just started
# Downloaded element 15 out of 677 total.
# For image number:  16 Just started
# Downloaded element 16 out of 677 total.
# For image number:  17 Just started
# Downloaded element 17 out of 677 total.
# For image number:  18 Just started
# Downloaded element 18 out of 677 total.
# For image number:  19 Just started
# Downloaded element 19 out of 677 total.
# For image number:  20 Just started
# Downloaded element 20 out of 677 total.
# For image number:  21 Just started
# Downloaded element 21 out of 677 total.
# For image number:  22 Just started
# Downloaded element 22 out of 677 total.
# For image number:  23 Just started
# Downloaded element 23 out of 677 total.
# For image number:  24 Just started
# Downloaded element 24 out of 677 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 677 total.
# For image number:  27 Just started
# Downloaded element 27 out of 677 total.
# For image number:  28 Just started
# Downloaded element 28 out of 677 total.
# For image number:  29 Just started
# Downloaded element 29 out of 677 total.
# For image number:  30 Just started
# Downloaded element 30 out of 677 total.
# For image number:  31 Just started
# Downloaded element 31 out of 677 total.
# For image number:  32 Just started
# Downloaded element 32 out of 677 total.
# For image number:  33 Just started
# Downloaded element 33 out of 677 total.
# For image number:  34 Just started
# Downloaded element 34 out of 677 total.
# For image number:  35 Just started
# Downloaded element 35 out of 677 total.
# For image number:  36 Just started
# Downloaded element 36 out of 677 total.
# For image number:  37 Just started
# Downloaded element 37 out of 677 total.
# For image number:  38 Just started
# Downloaded element 38 out of 677 total.
# For image number:  39 Just started
# Downloaded element 39 out of 677 total.
# For image number:  40 Just started
# For image number:  40 Could Not Find previewImageXpath
# For image number:  41 Just started
# For image number:  41 Could Not Find previewImageXpath
# For image number:  42 Just started
# For image number:  42 Could Not Find previewImageXpath
# For image number:  43 Just started
# Downloaded element 43 out of 677 total.
# For image number:  44 Just started
# For image number:  44 Could Not Find previewImageXpath
# For image number:  45 Just started
# Downloaded element 45 out of 677 total.
# For image number:  46 Just started
# Downloaded element 46 out of 677 total.
# For image number:  47 Just started
# Downloaded element 47 out of 677 total.
# For image number:  48 Just started
# Downloaded element 48 out of 677 total.
# For image number:  49 Just started
# Downloaded element 49 out of 677 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 677 total.
# For image number:  52 Just started
# Downloaded element 52 out of 677 total.
# For image number:  53 Just started
# Downloaded element 53 out of 677 total.
# For image number:  54 Just started
# Downloaded element 54 out of 677 total.
# For image number:  55 Just started
# Downloaded element 55 out of 677 total.
# For image number:  56 Just started
# Downloaded element 56 out of 677 total.
# Exceeded Length Doubt this occurs
# For class  56  The number of failures are  87
# len_containers for  Watermelon  is  605
# For image number:  1 Just started
# Downloaded element 1 out of 606 total.
# For image number:  2 Just started
# Downloaded element 2 out of 606 total.
# For image number:  3 Just started
# Downloaded element 3 out of 606 total.
# For image number:  4 Just started
# Downloaded element 4 out of 606 total.
# For image number:  5 Just started
# Downloaded element 5 out of 606 total.
# For image number:  6 Just started
# Downloaded element 6 out of 606 total.
# For image number:  7 Just started
# Downloaded element 7 out of 606 total.
# For image number:  8 Just started
# Downloaded element 8 out of 606 total.
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Downloaded element 10 out of 606 total.
# For image number:  11 Just started
# Downloaded element 11 out of 606 total.
# For image number:  12 Just started
# Downloaded element 12 out of 606 total.
# For image number:  13 Just started
# Downloaded element 13 out of 606 total.
# For image number:  14 Just started
# Downloaded element 14 out of 606 total.
# For image number:  15 Just started
# Downloaded element 15 out of 606 total.
# For image number:  16 Just started
# Downloaded element 16 out of 606 total.
# For image number:  17 Just started
# Downloaded element 17 out of 606 total.
# For image number:  18 Just started
# Downloaded element 18 out of 606 total.
# For image number:  19 Just started
# Downloaded element 19 out of 606 total.
# For image number:  20 Just started
# Downloaded element 20 out of 606 total.
# For image number:  21 Just started
# Downloaded element 21 out of 606 total.
# For image number:  22 Just started
# Downloaded element 22 out of 606 total.
# For image number:  23 Just started
# Downloaded element 23 out of 606 total.
# For image number:  24 Just started
# Downloaded element 24 out of 606 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 606 total.
# For image number:  27 Just started
# Downloaded element 27 out of 606 total.
# For image number:  28 Just started
# Downloaded element 28 out of 606 total.
# For image number:  29 Just started
# Downloaded element 29 out of 606 total.
# For image number:  30 Just started
# Downloaded element 30 out of 606 total.
# For image number:  31 Just started
# Downloaded element 31 out of 606 total.
# For image number:  32 Just started
# Downloaded element 32 out of 606 total.
# For image number:  33 Just started
# Downloaded element 33 out of 606 total.
# For image number:  34 Just started
# Downloaded element 34 out of 606 total.
# For image number:  35 Just started
# Downloaded element 35 out of 606 total.
# For image number:  36 Just started
# Downloaded element 36 out of 606 total.
# For image number:  37 Just started
# Downloaded element 37 out of 606 total.
# For image number:  38 Just started
# Downloaded element 38 out of 606 total.
# For image number:  39 Just started
# Downloaded element 39 out of 606 total.
# For image number:  40 Just started
# Downloaded element 40 out of 606 total.
# For image number:  41 Just started
# Downloaded element 41 out of 606 total.
# For image number:  42 Just started
# Downloaded element 42 out of 606 total.
# For image number:  43 Just started
# Downloaded element 43 out of 606 total.
# For image number:  44 Just started
# Downloaded element 44 out of 606 total.
# For image number:  45 Just started
# Downloaded element 45 out of 606 total.
# For image number:  46 Just started
# Downloaded element 46 out of 606 total.
# For image number:  47 Just started
# Downloaded element 47 out of 606 total.
# For image number:  48 Just started
# Downloaded element 48 out of 606 total.
# For image number:  49 Just started
# Downloaded element 49 out of 606 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 606 total.
# For image number:  52 Just started
# Downloaded element 52 out of 606 total.
# For image number:  53 Just started
# Downloaded element 53 out of 606 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  90

# %%
first=0
driver = webdriver.Chrome('C:\chromedriver.exe')
driver.get('https://www.google.co.in/imghp?hl=en&authuser=0&ogbl')
total_errors=0
for i in vegetables:
    desired_len=50
    first+=1
    folder_name = '..\\..\\final_dataset\\test\\'+i
    if not os.path.isdir(folder_name):
        os.makedirs(folder_name)
    else:
        tmp=os.listdir(folder_name)
        desired_len-=len(tmp)
        
    def download_image(url, folder_name, num):
        # write image to file
        reponse = requests.get(url)
        if reponse.status_code==200:
            with open(os.path.join(folder_name,str(num)+"_z.jpg"), 'wb') as file:
                file.write(reponse.content)
    if(first==1):
        box = driver.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
        box.send_keys(propery_dict[i]+' '+i+' Vegetable')
        box.send_keys(Keys.ENTER)
    else:
        box = driver.find_element('xpath','//*[@id="REsRA"]')
        for blah in range(10):
            box.send_keys(Keys.CONTROL+Keys.BACK_SPACE)
        box.send_keys(propery_dict[i]+' '+i+' Vegetable')
        box.send_keys(Keys.ENTER)
        

    
    last_height = driver.execute_script('return document.body.scrollHeight')
    counter=0
    while counter<12:
        driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
        time.sleep(2)
        new_height = driver.execute_script('return document.body.scrollHeight')
        try:
            driver.find_element('xpath','//*[@id="islmp"]/div/div/div/div[1]/div[2]/div[2]/input').click()
            counter+=1
            time.sleep(2)
        except:
            
            pass
        if new_height == last_height:
            break
        last_height = new_height

    #Scrolling all the way up
    driver.execute_script("window.scrollTo(0, 0);")
    page_html = driver.page_source
    pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
    containers = pageSoup.findAll('div', {'class':"isv-r PNCib MSM1fd BUooTd"} )
    len_containers = len(containers)
    print("len_containers for ",i," is ",len_containers)
    countersss=0
    for i in range(1, len_containers+1):        
        xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)
        print("For image number: ",i,"Just started")
        try:
            previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
            # print("For image number: ",i,"Found previewImageXpath")
            previewImageElement = driver.find_element('xpath',previewImageXPath)
            previewImageURL = previewImageElement.get_attribute("src")
            driver.find_element('xpath',xPath).click()
        except:
            print("For image number: ",i,"Could Not Find previewImageXpath")
            total_errors+=1
            continue

        timeStarted = time.time()
        # print("For image number: ",i,"Found ImageURL by clicking on that retriving src attribute")
        while True:
            try:              
#               #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img
                #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img
                imageElement = driver.find_element('xpath',"""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img""")
                imageURL= imageElement.get_attribute('src')
                
            
                if imageURL != previewImageURL:
                    #print("actual URL", imageURL)
                    # print("For image number: ",i," previewImageXpath and Image URL donot match")
                    break

                else:
                    # making a timeout if the full res image can't be loaded
                    currentTime = time.time()

                    if currentTime - timeStarted > 10:
        #                     print("Timeout! Will download a lower resolution image and move onto the next one")
                        # print("For image number: ",i,"Timeout")                    
                        break
            except:
                # print("For image number: ",i,"Could not Find ImageXpath")
                break
        


        try:
            download_image(imageURL, folder_name, i)
#             print("Downloaded element %s out of %s total. URL: %s" % (i, len_containers + 1, imageURL))
            print("Downloaded element %s out of %s total."%(i,len_containers+1))
            countersss+=1
            if(countersss>=desired_len):
                print("Exceeded Length Doubt this occurs")
                break
        except:
            total_errors+=1
            print("Couldn't download an image %s, continuing downloading the next one"%(i))
    print("For class ",i," The number of failures are ",total_errors)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_17292\2041815893.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\chromedriver.exe')
# len_containers for  Carrot  is  700
# For image number:  1 Just started
# Downloaded element 1 out of 701 total.
# For image number:  2 Just started
# Downloaded element 2 out of 701 total.
# For image number:  3 Just started
# Downloaded element 3 out of 701 total.
# For image number:  4 Just started
# Downloaded element 4 out of 701 total.
# For image number:  5 Just started
# Downloaded element 5 out of 701 total.
# For image number:  6 Just started
# Downloaded element 6 out of 701 total.
# For image number:  7 Just started
# Downloaded element 7 out of 701 total.
# For image number:  8 Just started
# Downloaded element 8 out of 701 total.
# For image number:  9 Just started
# Downloaded element 9 out of 701 total.
# For image number:  10 Just started
# Downloaded element 10 out of 701 total.
# For image number:  11 Just started
# Downloaded element 11 out of 701 total.
# For image number:  12 Just started
# Downloaded element 12 out of 701 total.
# For image number:  13 Just started
# Downloaded element 13 out of 701 total.
# For image number:  14 Just started
# Downloaded element 14 out of 701 total.
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Downloaded element 16 out of 701 total.
# For image number:  17 Just started
# Downloaded element 17 out of 701 total.
# For image number:  18 Just started
# Downloaded element 18 out of 701 total.
# For image number:  19 Just started
# Downloaded element 19 out of 701 total.
# For image number:  20 Just started
# Downloaded element 20 out of 701 total.
# For image number:  21 Just started
# Downloaded element 21 out of 701 total.
# For image number:  22 Just started
# Downloaded element 22 out of 701 total.
# For image number:  23 Just started
# Downloaded element 23 out of 701 total.
# For image number:  24 Just started
# Downloaded element 24 out of 701 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 701 total.
# For image number:  27 Just started
# Downloaded element 27 out of 701 total.
# For image number:  28 Just started
# Downloaded element 28 out of 701 total.
# For image number:  29 Just started
# Downloaded element 29 out of 701 total.
# For image number:  30 Just started
# Downloaded element 30 out of 701 total.
# For image number:  31 Just started
# Downloaded element 31 out of 701 total.
# For image number:  32 Just started
# Downloaded element 32 out of 701 total.
# For image number:  33 Just started
# Downloaded element 33 out of 701 total.
# For image number:  34 Just started
# Downloaded element 34 out of 701 total.
# For image number:  35 Just started
# Downloaded element 35 out of 701 total.
# For image number:  36 Just started
# Downloaded element 36 out of 701 total.
# For image number:  37 Just started
# Downloaded element 37 out of 701 total.
# For image number:  38 Just started
# Downloaded element 38 out of 701 total.
# For image number:  39 Just started
# Downloaded element 39 out of 701 total.
# For image number:  40 Just started
# Downloaded element 40 out of 701 total.
# For image number:  41 Just started
# Downloaded element 41 out of 701 total.
# For image number:  42 Just started
# Downloaded element 42 out of 701 total.
# For image number:  43 Just started
# Downloaded element 43 out of 701 total.
# For image number:  44 Just started
# Downloaded element 44 out of 701 total.
# For image number:  45 Just started
# Downloaded element 45 out of 701 total.
# For image number:  46 Just started
# Downloaded element 46 out of 701 total.
# For image number:  47 Just started
# Downloaded element 47 out of 701 total.
# For image number:  48 Just started
# Downloaded element 48 out of 701 total.
# For image number:  49 Just started
# Downloaded element 49 out of 701 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 701 total.
# For image number:  52 Just started
# Downloaded element 52 out of 701 total.
# For image number:  53 Just started
# Downloaded element 53 out of 701 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  3
# len_containers for  Potato  is  800
# For image number:  1 Just started
# Downloaded element 1 out of 801 total.
# For image number:  2 Just started
# Downloaded element 2 out of 801 total.
# For image number:  3 Just started
# Downloaded element 3 out of 801 total.
# For image number:  4 Just started
# Downloaded element 4 out of 801 total.
# For image number:  5 Just started
# Downloaded element 5 out of 801 total.
# For image number:  6 Just started
# Downloaded element 6 out of 801 total.
# For image number:  7 Just started
# Downloaded element 7 out of 801 total.
# For image number:  8 Just started
# Downloaded element 8 out of 801 total.
# For image number:  9 Just started
# Downloaded element 9 out of 801 total.
# For image number:  10 Just started
# Downloaded element 10 out of 801 total.
# For image number:  11 Just started
# Downloaded element 11 out of 801 total.
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Downloaded element 13 out of 801 total.
# For image number:  14 Just started
# Downloaded element 14 out of 801 total.
# For image number:  15 Just started
# Downloaded element 15 out of 801 total.
# For image number:  16 Just started
# Downloaded element 16 out of 801 total.
# For image number:  17 Just started
# Downloaded element 17 out of 801 total.
# For image number:  18 Just started
# Downloaded element 18 out of 801 total.
# For image number:  19 Just started
# Downloaded element 19 out of 801 total.
# For image number:  20 Just started
# Downloaded element 20 out of 801 total.
# For image number:  21 Just started
# Downloaded element 21 out of 801 total.
# For image number:  22 Just started
# Downloaded element 22 out of 801 total.
# For image number:  23 Just started
# Downloaded element 23 out of 801 total.
# For image number:  24 Just started
# Downloaded element 24 out of 801 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 801 total.
# For image number:  27 Just started
# Downloaded element 27 out of 801 total.
# For image number:  28 Just started
# Downloaded element 28 out of 801 total.
# For image number:  29 Just started
# Downloaded element 29 out of 801 total.
# For image number:  30 Just started
# Downloaded element 30 out of 801 total.
# For image number:  31 Just started
# Downloaded element 31 out of 801 total.
# For image number:  32 Just started
# Downloaded element 32 out of 801 total.
# For image number:  33 Just started
# Downloaded element 33 out of 801 total.
# For image number:  34 Just started
# Downloaded element 34 out of 801 total.
# For image number:  35 Just started
# Downloaded element 35 out of 801 total.
# For image number:  36 Just started
# Downloaded element 36 out of 801 total.
# For image number:  37 Just started
# Downloaded element 37 out of 801 total.
# For image number:  38 Just started
# Downloaded element 38 out of 801 total.
# For image number:  39 Just started
# Downloaded element 39 out of 801 total.
# For image number:  40 Just started
# Downloaded element 40 out of 801 total.
# For image number:  41 Just started
# Downloaded element 41 out of 801 total.
# For image number:  42 Just started
# Downloaded element 42 out of 801 total.
# For image number:  43 Just started
# Downloaded element 43 out of 801 total.
# For image number:  44 Just started
# Downloaded element 44 out of 801 total.
# For image number:  45 Just started
# Downloaded element 45 out of 801 total.
# For image number:  46 Just started
# Downloaded element 46 out of 801 total.
# For image number:  47 Just started
# Downloaded element 47 out of 801 total.
# For image number:  48 Just started
# Downloaded element 48 out of 801 total.
# For image number:  49 Just started
# Downloaded element 49 out of 801 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 801 total.
# For image number:  52 Just started
# Downloaded element 52 out of 801 total.
# For image number:  53 Just started
# Downloaded element 53 out of 801 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  6
# len_containers for  Onion  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Couldn't download an image 7, continuing downloading the next one
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Couldn't download an image 14, continuing downloading the next one
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  27
# len_containers for  Beetroot  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Couldn't download an image 7, continuing downloading the next one
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Couldn't download an image 14, continuing downloading the next one
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  48
# len_containers for  Peas  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Couldn't download an image 7, continuing downloading the next one
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Downloaded element 13 out of 49 total.
# For image number:  14 Just started
# Downloaded element 14 out of 49 total.
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  67
# len_containers for  Bean  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Couldn't download an image 7, continuing downloading the next one
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Couldn't download an image 14, continuing downloading the next one
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  88
# len_containers for  Ginger  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Couldn't download an image 7, continuing downloading the next one
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Couldn't download an image 14, continuing downloading the next one
# For image number:  15 Just started
# Downloaded element 15 out of 49 total.
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  108
# len_containers for  Garlic  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Downloaded element 3 out of 49 total.
# For image number:  4 Just started
# Downloaded element 4 out of 49 total.
# For image number:  5 Just started
# Downloaded element 5 out of 49 total.
# For image number:  6 Just started
# Downloaded element 6 out of 49 total.
# For image number:  7 Just started
# Downloaded element 7 out of 49 total.
# For image number:  8 Just started
# Downloaded element 8 out of 49 total.
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Downloaded element 10 out of 49 total.
# For image number:  11 Just started
# Downloaded element 11 out of 49 total.
# For image number:  12 Just started
# Downloaded element 12 out of 49 total.
# For image number:  13 Just started
# Downloaded element 13 out of 49 total.
# For image number:  14 Just started
# Downloaded element 14 out of 49 total.
# For image number:  15 Just started
# Downloaded element 15 out of 49 total.
# For image number:  16 Just started
# Downloaded element 16 out of 49 total.
# For image number:  17 Just started
# Downloaded element 17 out of 49 total.
# For image number:  18 Just started
# Downloaded element 18 out of 49 total.
# For image number:  19 Just started
# Downloaded element 19 out of 49 total.
# For image number:  20 Just started
# Downloaded element 20 out of 49 total.
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  112
# len_containers for  Cabbage  is  756
# For image number:  1 Just started
# Downloaded element 1 out of 757 total.
# For image number:  2 Just started
# Downloaded element 2 out of 757 total.
# For image number:  3 Just started
# Downloaded element 3 out of 757 total.
# For image number:  4 Just started
# Downloaded element 4 out of 757 total.
# For image number:  5 Just started
# Downloaded element 5 out of 757 total.
# For image number:  6 Just started
# Downloaded element 6 out of 757 total.
# For image number:  7 Just started
# Downloaded element 7 out of 757 total.
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Downloaded element 9 out of 757 total.
# For image number:  10 Just started
# Downloaded element 10 out of 757 total.
# For image number:  11 Just started
# Downloaded element 11 out of 757 total.
# For image number:  12 Just started
# Downloaded element 12 out of 757 total.
# For image number:  13 Just started
# Downloaded element 13 out of 757 total.
# For image number:  14 Just started
# Downloaded element 14 out of 757 total.
# For image number:  15 Just started
# Downloaded element 15 out of 757 total.
# For image number:  16 Just started
# Downloaded element 16 out of 757 total.
# For image number:  17 Just started
# Downloaded element 17 out of 757 total.
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Downloaded element 19 out of 757 total.
# For image number:  20 Just started
# Downloaded element 20 out of 757 total.
# For image number:  21 Just started
# Downloaded element 21 out of 757 total.
# For image number:  22 Just started
# Downloaded element 22 out of 757 total.
# For image number:  23 Just started
# Downloaded element 23 out of 757 total.
# For image number:  24 Just started
# Downloaded element 24 out of 757 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 757 total.
# For image number:  27 Just started
# Downloaded element 27 out of 757 total.
# For image number:  28 Just started
# Downloaded element 28 out of 757 total.
# For image number:  29 Just started
# Downloaded element 29 out of 757 total.
# For image number:  30 Just started
# Downloaded element 30 out of 757 total.
# For image number:  31 Just started
# Downloaded element 31 out of 757 total.
# For image number:  32 Just started
# Downloaded element 32 out of 757 total.
# For image number:  33 Just started
# Downloaded element 33 out of 757 total.
# For image number:  34 Just started
# Downloaded element 34 out of 757 total.
# For image number:  35 Just started
# Downloaded element 35 out of 757 total.
# For image number:  36 Just started
# Downloaded element 36 out of 757 total.
# For image number:  37 Just started
# Downloaded element 37 out of 757 total.
# For image number:  38 Just started
# Downloaded element 38 out of 757 total.
# For image number:  39 Just started
# Downloaded element 39 out of 757 total.
# For image number:  40 Just started
# Downloaded element 40 out of 757 total.
# For image number:  41 Just started
# Downloaded element 41 out of 757 total.
# For image number:  42 Just started
# Downloaded element 42 out of 757 total.
# For image number:  43 Just started
# Downloaded element 43 out of 757 total.
# For image number:  44 Just started
# Downloaded element 44 out of 757 total.
# For image number:  45 Just started
# Downloaded element 45 out of 757 total.
# For image number:  46 Just started
# Downloaded element 46 out of 757 total.
# For image number:  47 Just started
# Downloaded element 47 out of 757 total.
# For image number:  48 Just started
# Downloaded element 48 out of 757 total.
# For image number:  49 Just started
# Downloaded element 49 out of 757 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 757 total.
# For image number:  52 Just started
# Downloaded element 52 out of 757 total.
# For image number:  53 Just started
# Downloaded element 53 out of 757 total.
# For image number:  54 Just started
# Downloaded element 54 out of 757 total.
# Exceeded Length Doubt this occurs
# For class  54  The number of failures are  116
# len_containers for  Cucumber  is  715
# For image number:  1 Just started
# Downloaded element 1 out of 716 total.
# For image number:  2 Just started
# Downloaded element 2 out of 716 total.
# For image number:  3 Just started
# Downloaded element 3 out of 716 total.
# For image number:  4 Just started
# Downloaded element 4 out of 716 total.
# For image number:  5 Just started
# Downloaded element 5 out of 716 total.
# For image number:  6 Just started
# Downloaded element 6 out of 716 total.
# For image number:  7 Just started
# Downloaded element 7 out of 716 total.
# For image number:  8 Just started
# Downloaded element 8 out of 716 total.
# For image number:  9 Just started
# Downloaded element 9 out of 716 total.
# For image number:  10 Just started
# Downloaded element 10 out of 716 total.
# For image number:  11 Just started
# Downloaded element 11 out of 716 total.
# For image number:  12 Just started
# Downloaded element 12 out of 716 total.
# For image number:  13 Just started
# Downloaded element 13 out of 716 total.
# For image number:  14 Just started
# Downloaded element 14 out of 716 total.
# For image number:  15 Just started
# Downloaded element 15 out of 716 total.
# For image number:  16 Just started
# Downloaded element 16 out of 716 total.
# For image number:  17 Just started
# Downloaded element 17 out of 716 total.
# For image number:  18 Just started
# Downloaded element 18 out of 716 total.
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Downloaded element 20 out of 716 total.
# For image number:  21 Just started
# Downloaded element 21 out of 716 total.
# For image number:  22 Just started
# Downloaded element 22 out of 716 total.
# For image number:  23 Just started
# Downloaded element 23 out of 716 total.
# For image number:  24 Just started
# Downloaded element 24 out of 716 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 716 total.
# For image number:  27 Just started
# Downloaded element 27 out of 716 total.
# For image number:  28 Just started
# Downloaded element 28 out of 716 total.
# For image number:  29 Just started
# Downloaded element 29 out of 716 total.
# For image number:  30 Just started
# Downloaded element 30 out of 716 total.
# For image number:  31 Just started
# Downloaded element 31 out of 716 total.
# For image number:  32 Just started
# Downloaded element 32 out of 716 total.
# For image number:  33 Just started
# Downloaded element 33 out of 716 total.
# For image number:  34 Just started
# Downloaded element 34 out of 716 total.
# For image number:  35 Just started
# Downloaded element 35 out of 716 total.
# For image number:  36 Just started
# Downloaded element 36 out of 716 total.
# For image number:  37 Just started
# Downloaded element 37 out of 716 total.
# For image number:  38 Just started
# Downloaded element 38 out of 716 total.
# For image number:  39 Just started
# Downloaded element 39 out of 716 total.
# For image number:  40 Just started
# Downloaded element 40 out of 716 total.
# For image number:  41 Just started
# Downloaded element 41 out of 716 total.
# For image number:  42 Just started
# Downloaded element 42 out of 716 total.
# For image number:  43 Just started
# Downloaded element 43 out of 716 total.
# For image number:  44 Just started
# Downloaded element 44 out of 716 total.
# For image number:  45 Just started
# Downloaded element 45 out of 716 total.
# For image number:  46 Just started
# Downloaded element 46 out of 716 total.
# For image number:  47 Just started
# Downloaded element 47 out of 716 total.
# For image number:  48 Just started
# Downloaded element 48 out of 716 total.
# For image number:  49 Just started
# Downloaded element 49 out of 716 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 716 total.
# For image number:  52 Just started
# Downloaded element 52 out of 716 total.
# For image number:  53 Just started
# Downloaded element 53 out of 716 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  119
# len_containers for  Sweet potato  is  600
# For image number:  1 Just started
# Downloaded element 1 out of 601 total.
# For image number:  2 Just started
# Downloaded element 2 out of 601 total.
# For image number:  3 Just started
# Downloaded element 3 out of 601 total.
# For image number:  4 Just started
# Downloaded element 4 out of 601 total.
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Couldn't download an image 7, continuing downloading the next one
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Couldn't download an image 9, continuing downloading the next one
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Couldn't download an image 14, continuing downloading the next one
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 601 total.
# For image number:  22 Just started
# Downloaded element 22 out of 601 total.
# For image number:  23 Just started
# Downloaded element 23 out of 601 total.
# For image number:  24 Just started
# Downloaded element 24 out of 601 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 601 total.
# For image number:  27 Just started
# Downloaded element 27 out of 601 total.
# For image number:  28 Just started
# Downloaded element 28 out of 601 total.
# For image number:  29 Just started
# Downloaded element 29 out of 601 total.
# For image number:  30 Just started
# Downloaded element 30 out of 601 total.
# For image number:  31 Just started
# Downloaded element 31 out of 601 total.
# For image number:  32 Just started
# Downloaded element 32 out of 601 total.
# For image number:  33 Just started
# Downloaded element 33 out of 601 total.
# For image number:  34 Just started
# Downloaded element 34 out of 601 total.
# For image number:  35 Just started
# Downloaded element 35 out of 601 total.
# For image number:  36 Just started
# Downloaded element 36 out of 601 total.
# For image number:  37 Just started
# Downloaded element 37 out of 601 total.
# For image number:  38 Just started
# Downloaded element 38 out of 601 total.
# For image number:  39 Just started
# Downloaded element 39 out of 601 total.
# For image number:  40 Just started
# Downloaded element 40 out of 601 total.
# For image number:  41 Just started
# Downloaded element 41 out of 601 total.
# For image number:  42 Just started
# Downloaded element 42 out of 601 total.
# For image number:  43 Just started
# Downloaded element 43 out of 601 total.
# For image number:  44 Just started
# Downloaded element 44 out of 601 total.
# For image number:  45 Just started
# Downloaded element 45 out of 601 total.
# For image number:  46 Just started
# Downloaded element 46 out of 601 total.
# For image number:  47 Just started
# Downloaded element 47 out of 601 total.
# For image number:  48 Just started
# Downloaded element 48 out of 601 total.
# For image number:  49 Just started
# Downloaded element 49 out of 601 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 601 total.
# For image number:  52 Just started
# Downloaded element 52 out of 601 total.
# For image number:  53 Just started
# Downloaded element 53 out of 601 total.
# For image number:  54 Just started
# Downloaded element 54 out of 601 total.
# For image number:  55 Just started
# Downloaded element 55 out of 601 total.
# For image number:  56 Just started
# Downloaded element 56 out of 601 total.
# For image number:  57 Just started
# Downloaded element 57 out of 601 total.
# For image number:  58 Just started
# Downloaded element 58 out of 601 total.
# For image number:  59 Just started
# Downloaded element 59 out of 601 total.
# For image number:  60 Just started
# Downloaded element 60 out of 601 total.
# For image number:  61 Just started
# Downloaded element 61 out of 601 total.
# For image number:  62 Just started
# Downloaded element 62 out of 601 total.
# For image number:  63 Just started
# Downloaded element 63 out of 601 total.
# For image number:  64 Just started
# Downloaded element 64 out of 601 total.
# For image number:  65 Just started
# Downloaded element 65 out of 601 total.
# For image number:  66 Just started
# Downloaded element 66 out of 601 total.
# For image number:  67 Just started
# Downloaded element 67 out of 601 total.
# For image number:  68 Just started
# Downloaded element 68 out of 601 total.
# Exceeded Length Doubt this occurs
# For class  68  The number of failures are  137
# len_containers for  Radish  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Couldn't download an image 6, continuing downloading the next one
# For image number:  7 Just started
# Downloaded element 7 out of 49 total.
# For image number:  8 Just started
# Downloaded element 8 out of 49 total.
# For image number:  9 Just started
# Downloaded element 9 out of 49 total.
# For image number:  10 Just started
# ...
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Couldn't download an image 3, continuing downloading the next one
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Downloaded element 6 out of 49 total.
# For image number:  7 Just started
# Downloaded element 7 out of 49 total.
# For image number:  8 Just started
# Downloaded element 8 out of 49 total.
# For image number:  9 Just started
# Downloaded element 9 out of 49 total.
# For image number:  10 Just started
# Couldn't download an image 10, continuing downloading the next one
# For image number:  11 Just started
# Couldn't download an image 11, continuing downloading the next one
# For image number:  12 Just started
# Couldn't download an image 12, continuing downloading the next one
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Couldn't download an image 14, continuing downloading the next one
# For image number:  15 Just started
# Couldn't download an image 15, continuing downloading the next one
# For image number:  16 Just started
# Couldn't download an image 16, continuing downloading the next one
# For image number:  17 Just started
# Couldn't download an image 17, continuing downloading the next one
# For image number:  18 Just started
# Couldn't download an image 18, continuing downloading the next one
# For image number:  19 Just started
# Couldn't download an image 19, continuing downloading the next one
# For image number:  20 Just started
# Couldn't download an image 20, continuing downloading the next one
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Downloaded element 22 out of 49 total.
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  283
# len_containers for  Cauliflower  is  48
# For image number:  1 Just started
# Couldn't download an image 1, continuing downloading the next one
# For image number:  2 Just started
# Couldn't download an image 2, continuing downloading the next one
# For image number:  3 Just started
# Downloaded element 3 out of 49 total.
# For image number:  4 Just started
# Downloaded element 4 out of 49 total.
# For image number:  5 Just started
# Downloaded element 5 out of 49 total.
# For image number:  6 Just started
# Downloaded element 6 out of 49 total.
# For image number:  7 Just started
# Downloaded element 7 out of 49 total.
# For image number:  8 Just started
# Couldn't download an image 8, continuing downloading the next one
# For image number:  9 Just started
# Downloaded element 9 out of 49 total.
# For image number:  10 Just started
# Downloaded element 10 out of 49 total.
# For image number:  11 Just started
# Downloaded element 11 out of 49 total.
# For image number:  12 Just started
# Downloaded element 12 out of 49 total.
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Downloaded element 14 out of 49 total.
# For image number:  15 Just started
# Downloaded element 15 out of 49 total.
# For image number:  16 Just started
# Downloaded element 16 out of 49 total.
# For image number:  17 Just started
# Downloaded element 17 out of 49 total.
# For image number:  18 Just started
# Downloaded element 18 out of 49 total.
# For image number:  19 Just started
# Downloaded element 19 out of 49 total.
# For image number:  20 Just started
# Downloaded element 20 out of 49 total.
# For image number:  21 Just started
# Downloaded element 21 out of 49 total.
# For image number:  22 Just started
# Couldn't download an image 22, continuing downloading the next one
# For image number:  23 Just started
# Downloaded element 23 out of 49 total.
# For image number:  24 Just started
# Downloaded element 24 out of 49 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 49 total.
# For image number:  27 Just started
# Downloaded element 27 out of 49 total.
# For image number:  28 Just started
# Downloaded element 28 out of 49 total.
# For image number:  29 Just started
# Downloaded element 29 out of 49 total.
# For image number:  30 Just started
# Downloaded element 30 out of 49 total.
# For image number:  31 Just started
# Downloaded element 31 out of 49 total.
# For image number:  32 Just started
# Downloaded element 32 out of 49 total.
# For image number:  33 Just started
# Downloaded element 33 out of 49 total.
# For image number:  34 Just started
# Downloaded element 34 out of 49 total.
# For image number:  35 Just started
# Downloaded element 35 out of 49 total.
# For image number:  36 Just started
# Downloaded element 36 out of 49 total.
# For image number:  37 Just started
# Downloaded element 37 out of 49 total.
# For image number:  38 Just started
# Downloaded element 38 out of 49 total.
# For image number:  39 Just started
# Downloaded element 39 out of 49 total.
# For image number:  40 Just started
# Downloaded element 40 out of 49 total.
# For image number:  41 Just started
# Downloaded element 41 out of 49 total.
# For image number:  42 Just started
# Downloaded element 42 out of 49 total.
# For image number:  43 Just started
# Downloaded element 43 out of 49 total.
# For image number:  44 Just started
# Downloaded element 44 out of 49 total.
# For image number:  45 Just started
# Downloaded element 45 out of 49 total.
# For image number:  46 Just started
# Downloaded element 46 out of 49 total.
# For image number:  47 Just started
# Downloaded element 47 out of 49 total.
# For image number:  48 Just started
# Downloaded element 48 out of 49 total.
# For class  48  The number of failures are  289
# len_containers for  Pumpkin  is  692
# For image number:  1 Just started
# Downloaded element 1 out of 693 total.
# For image number:  2 Just started
# Downloaded element 2 out of 693 total.
# For image number:  3 Just started
# Downloaded element 3 out of 693 total.
# For image number:  4 Just started
# Couldn't download an image 4, continuing downloading the next one
# For image number:  5 Just started
# Downloaded element 5 out of 693 total.
# For image number:  6 Just started
# Downloaded element 6 out of 693 total.
# For image number:  7 Just started
# Downloaded element 7 out of 693 total.
# For image number:  8 Just started
# Downloaded element 8 out of 693 total.
# For image number:  9 Just started
# Downloaded element 9 out of 693 total.
# For image number:  10 Just started
# Downloaded element 10 out of 693 total.
# For image number:  11 Just started
# Downloaded element 11 out of 693 total.
# For image number:  12 Just started
# Downloaded element 12 out of 693 total.
# For image number:  13 Just started
# Downloaded element 13 out of 693 total.
# For image number:  14 Just started
# Downloaded element 14 out of 693 total.
# For image number:  15 Just started
# Downloaded element 15 out of 693 total.
# For image number:  16 Just started
# Downloaded element 16 out of 693 total.
# For image number:  17 Just started
# Downloaded element 17 out of 693 total.
# For image number:  18 Just started
# Downloaded element 18 out of 693 total.
# For image number:  19 Just started
# Downloaded element 19 out of 693 total.
# For image number:  20 Just started
# Downloaded element 20 out of 693 total.
# For image number:  21 Just started
# Downloaded element 21 out of 693 total.
# For image number:  22 Just started
# Downloaded element 22 out of 693 total.
# For image number:  23 Just started
# Downloaded element 23 out of 693 total.
# For image number:  24 Just started
# Downloaded element 24 out of 693 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 693 total.
# For image number:  27 Just started
# Downloaded element 27 out of 693 total.
# For image number:  28 Just started
# Downloaded element 28 out of 693 total.
# For image number:  29 Just started
# Downloaded element 29 out of 693 total.
# For image number:  30 Just started
# Downloaded element 30 out of 693 total.
# For image number:  31 Just started
# Downloaded element 31 out of 693 total.
# For image number:  32 Just started
# Downloaded element 32 out of 693 total.
# For image number:  33 Just started
# Downloaded element 33 out of 693 total.
# For image number:  34 Just started
# Downloaded element 34 out of 693 total.
# For image number:  35 Just started
# Downloaded element 35 out of 693 total.
# For image number:  36 Just started
# Downloaded element 36 out of 693 total.
# For image number:  37 Just started
# Downloaded element 37 out of 693 total.
# For image number:  38 Just started
# Downloaded element 38 out of 693 total.
# For image number:  39 Just started
# Downloaded element 39 out of 693 total.
# For image number:  40 Just started
# Downloaded element 40 out of 693 total.
# For image number:  41 Just started
# Downloaded element 41 out of 693 total.
# For image number:  42 Just started
# Downloaded element 42 out of 693 total.
# For image number:  43 Just started
# Downloaded element 43 out of 693 total.
# For image number:  44 Just started
# Downloaded element 44 out of 693 total.
# For image number:  45 Just started
# Downloaded element 45 out of 693 total.
# For image number:  46 Just started
# Downloaded element 46 out of 693 total.
# For image number:  47 Just started
# Downloaded element 47 out of 693 total.
# For image number:  48 Just started
# Downloaded element 48 out of 693 total.
# For image number:  49 Just started
# Downloaded element 49 out of 693 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 693 total.
# For image number:  52 Just started
# Downloaded element 52 out of 693 total.
# For image number:  53 Just started
# Downloaded element 53 out of 693 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  292
# len_containers for  Bottle gourd  is  620
# For image number:  1 Just started
# Downloaded element 1 out of 621 total.
# For image number:  2 Just started
# Downloaded element 2 out of 621 total.
# For image number:  3 Just started
# Downloaded element 3 out of 621 total.
# For image number:  4 Just started
# Downloaded element 4 out of 621 total.
# For image number:  5 Just started
# Couldn't download an image 5, continuing downloading the next one
# For image number:  6 Just started
# Downloaded element 6 out of 621 total.
# For image number:  7 Just started
# Downloaded element 7 out of 621 total.
# For image number:  8 Just started
# Downloaded element 8 out of 621 total.
# For image number:  9 Just started
# Downloaded element 9 out of 621 total.
# For image number:  10 Just started
# Downloaded element 10 out of 621 total.
# For image number:  11 Just started
# Downloaded element 11 out of 621 total.
# For image number:  12 Just started
# Downloaded element 12 out of 621 total.
# For image number:  13 Just started
# Downloaded element 13 out of 621 total.
# For image number:  14 Just started
# Downloaded element 14 out of 621 total.
# For image number:  15 Just started
# Downloaded element 15 out of 621 total.
# For image number:  16 Just started
# Downloaded element 16 out of 621 total.
# For image number:  17 Just started
# Downloaded element 17 out of 621 total.
# For image number:  18 Just started
# Downloaded element 18 out of 621 total.
# For image number:  19 Just started
# Downloaded element 19 out of 621 total.
# For image number:  20 Just started
# Downloaded element 20 out of 621 total.
# For image number:  21 Just started
# Downloaded element 21 out of 621 total.
# For image number:  22 Just started
# Downloaded element 22 out of 621 total.
# For image number:  23 Just started
# Downloaded element 23 out of 621 total.
# For image number:  24 Just started
# Downloaded element 24 out of 621 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 621 total.
# For image number:  27 Just started
# Downloaded element 27 out of 621 total.
# For image number:  28 Just started
# Downloaded element 28 out of 621 total.
# For image number:  29 Just started
# Downloaded element 29 out of 621 total.
# For image number:  30 Just started
# Downloaded element 30 out of 621 total.
# For image number:  31 Just started
# Downloaded element 31 out of 621 total.
# For image number:  32 Just started
# Downloaded element 32 out of 621 total.
# For image number:  33 Just started
# Downloaded element 33 out of 621 total.
# For image number:  34 Just started
# Downloaded element 34 out of 621 total.
# For image number:  35 Just started
# Downloaded element 35 out of 621 total.
# For image number:  36 Just started
# Downloaded element 36 out of 621 total.
# For image number:  37 Just started
# Downloaded element 37 out of 621 total.
# For image number:  38 Just started
# Downloaded element 38 out of 621 total.
# For image number:  39 Just started
# Downloaded element 39 out of 621 total.
# For image number:  40 Just started
# Downloaded element 40 out of 621 total.
# For image number:  41 Just started
# Downloaded element 41 out of 621 total.
# For image number:  42 Just started
# Downloaded element 42 out of 621 total.
# For image number:  43 Just started
# Downloaded element 43 out of 621 total.
# For image number:  44 Just started
# Downloaded element 44 out of 621 total.
# For image number:  45 Just started
# Downloaded element 45 out of 621 total.
# For image number:  46 Just started
# Downloaded element 46 out of 621 total.
# For image number:  47 Just started
# Downloaded element 47 out of 621 total.
# For image number:  48 Just started
# Downloaded element 48 out of 621 total.
# For image number:  49 Just started
# Downloaded element 49 out of 621 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 621 total.
# For image number:  52 Just started
# Downloaded element 52 out of 621 total.
# For image number:  53 Just started
# Downloaded element 53 out of 621 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  295

# %%
temp_veggies=["Carrot","Cauliflower"]
temp_fruits=["Strawberry"]
propery_dict["Strawberry"]="Red"
propery_dict["Carrot"]=""
propery_dict["Cauliflower"]="White"
first=0
driver = webdriver.Chrome('C:\chromedriver.exe')
driver.get('https://www.google.co.in/imghp?hl=en&authuser=0&ogbl')
total_errors=0
for i in temp_fruits:
    desired_len=50
    first+=1
    folder_name = '..\\..\\final_dataset\\test\\'+i
    if not os.path.isdir(folder_name):
        os.makedirs(folder_name)
    else:
        tmp=os.listdir(folder_name)
        desired_len-=len(tmp)
        
    def download_image(url, folder_name, num):
        # write image to file
        reponse = requests.get(url)
        if reponse.status_code==200:
            with open(os.path.join(folder_name,str(num)+"_z.jpg"), 'wb') as file:
                file.write(reponse.content)
    if(first==1):
        box = driver.find_element('xpath','/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
        box.send_keys(propery_dict[i]+' '+i+' Fruit')
        box.send_keys(Keys.ENTER)
    else:
        box = driver.find_element('xpath','//*[@id="REsRA"]')
        for blah in range(10):
            box.send_keys(Keys.CONTROL+Keys.BACK_SPACE)
        box.send_keys(propery_dict[i]+' '+i+' Fruit')
        box.send_keys(Keys.ENTER)
        

    
    last_height = driver.execute_script('return document.body.scrollHeight')
    counter=0
    while counter<12:
        driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
        time.sleep(2)
        new_height = driver.execute_script('return document.body.scrollHeight')
        try:
            driver.find_element('xpath','//*[@id="islmp"]/div/div/div/div[1]/div[2]/div[2]/input').click()
            counter+=1
            time.sleep(2)
        except:
            
            pass
        if new_height == last_height:
            break
        last_height = new_height

    #Scrolling all the way up
    driver.execute_script("window.scrollTo(0, 0);")
    page_html = driver.page_source
    pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
    containers = pageSoup.findAll('div', {'class':"isv-r PNCib MSM1fd BUooTd"} )
    len_containers = len(containers)
    print("len_containers for ",i," is ",len_containers)
    countersss=0
    for i in range(1, len_containers+1):        
        xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)
        print("For image number: ",i,"Just started")
        try:
            previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
            # print("For image number: ",i,"Found previewImageXpath")
            previewImageElement = driver.find_element('xpath',previewImageXPath)
            previewImageURL = previewImageElement.get_attribute("src")
            driver.find_element('xpath',xPath).click()
        except:
            print("For image number: ",i,"Could Not Find previewImageXpath")
            total_errors+=1
            continue

        timeStarted = time.time()
        # print("For image number: ",i,"Found ImageURL by clicking on that retriving src attribute")
        while True:
            try:              
#               #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img
                #//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img
                imageElement = driver.find_element('xpath',"""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img""")
                imageURL= imageElement.get_attribute('src')
                
            
                if imageURL != previewImageURL:
                    #print("actual URL", imageURL)
                    # print("For image number: ",i," previewImageXpath and Image URL donot match")
                    break

                else:
                    # making a timeout if the full res image can't be loaded
                    currentTime = time.time()

                    if currentTime - timeStarted > 10:
        #                     print("Timeout! Will download a lower resolution image and move onto the next one")
                        # print("For image number: ",i,"Timeout")                    
                        break
            except:
                # print("For image number: ",i,"Could not Find ImageXpath")
                break
        


        try:
            download_image(imageURL, folder_name, i)
#             print("Downloaded element %s out of %s total. URL: %s" % (i, len_containers + 1, imageURL))
            print("Downloaded element %s out of %s total."%(i,len_containers+1))
            countersss+=1
            if(countersss>=desired_len):
                print("Exceeded Length Doubt this occurs")
                break
        except:
            total_errors+=1
            print("Couldn't download an image %s, continuing downloading the next one"%(i))
    print("For class ",i," The number of failures are ",total_errors)
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_21764\3680646069.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\chromedriver.exe')
# len_containers for  Strawberry  is  836
# For image number:  1 Just started
# Downloaded element 1 out of 837 total.
# For image number:  2 Just started
# Downloaded element 2 out of 837 total.
# For image number:  3 Just started
# Downloaded element 3 out of 837 total.
# For image number:  4 Just started
# Downloaded element 4 out of 837 total.
# For image number:  5 Just started
# Downloaded element 5 out of 837 total.
# For image number:  6 Just started
# Downloaded element 6 out of 837 total.
# For image number:  7 Just started
# Downloaded element 7 out of 837 total.
# For image number:  8 Just started
# Downloaded element 8 out of 837 total.
# For image number:  9 Just started
# Downloaded element 9 out of 837 total.
# For image number:  10 Just started
# Downloaded element 10 out of 837 total.
# For image number:  11 Just started
# Downloaded element 11 out of 837 total.
# For image number:  12 Just started
# Downloaded element 12 out of 837 total.
# For image number:  13 Just started
# Couldn't download an image 13, continuing downloading the next one
# For image number:  14 Just started
# Downloaded element 14 out of 837 total.
# For image number:  15 Just started
# Downloaded element 15 out of 837 total.
# For image number:  16 Just started
# Downloaded element 16 out of 837 total.
# For image number:  17 Just started
# Downloaded element 17 out of 837 total.
# For image number:  18 Just started
# Downloaded element 18 out of 837 total.
# For image number:  19 Just started
# Downloaded element 19 out of 837 total.
# For image number:  20 Just started
# Downloaded element 20 out of 837 total.
# For image number:  21 Just started
# Downloaded element 21 out of 837 total.
# For image number:  22 Just started
# Downloaded element 22 out of 837 total.
# For image number:  23 Just started
# Downloaded element 23 out of 837 total.
# For image number:  24 Just started
# Downloaded element 24 out of 837 total.
# For image number:  25 Just started
# For image number:  25 Could Not Find previewImageXpath
# For image number:  26 Just started
# Downloaded element 26 out of 837 total.
# For image number:  27 Just started
# Downloaded element 27 out of 837 total.
# For image number:  28 Just started
# Downloaded element 28 out of 837 total.
# For image number:  29 Just started
# Downloaded element 29 out of 837 total.
# For image number:  30 Just started
# Downloaded element 30 out of 837 total.
# For image number:  31 Just started
# Downloaded element 31 out of 837 total.
# For image number:  32 Just started
# Downloaded element 32 out of 837 total.
# For image number:  33 Just started
# Downloaded element 33 out of 837 total.
# For image number:  34 Just started
# Downloaded element 34 out of 837 total.
# For image number:  35 Just started
# Downloaded element 35 out of 837 total.
# For image number:  36 Just started
# Downloaded element 36 out of 837 total.
# For image number:  37 Just started
# Downloaded element 37 out of 837 total.
# For image number:  38 Just started
# Downloaded element 38 out of 837 total.
# For image number:  39 Just started
# Downloaded element 39 out of 837 total.
# For image number:  40 Just started
# Downloaded element 40 out of 837 total.
# For image number:  41 Just started
# Downloaded element 41 out of 837 total.
# For image number:  42 Just started
# Downloaded element 42 out of 837 total.
# For image number:  43 Just started
# Downloaded element 43 out of 837 total.
# For image number:  44 Just started
# Downloaded element 44 out of 837 total.
# For image number:  45 Just started
# Downloaded element 45 out of 837 total.
# For image number:  46 Just started
# Downloaded element 46 out of 837 total.
# For image number:  47 Just started
# Downloaded element 47 out of 837 total.
# For image number:  48 Just started
# Downloaded element 48 out of 837 total.
# For image number:  49 Just started
# Downloaded element 49 out of 837 total.
# For image number:  50 Just started
# For image number:  50 Could Not Find previewImageXpath
# For image number:  51 Just started
# Downloaded element 51 out of 837 total.
# For image number:  52 Just started
# Downloaded element 52 out of 837 total.
# For image number:  53 Just started
# Downloaded element 53 out of 837 total.
# Exceeded Length Doubt this occurs
# For class  53  The number of failures are  3
